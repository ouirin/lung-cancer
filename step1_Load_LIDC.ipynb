# %%
import settings
import helpers
import SimpleITK  # conda install -c https://conda.anaconda.org/simpleitk SimpleITK
import numpy
import pandas
import ntpath

import cv2  # conda install -c https://conda.anaconda.org/menpo opencv3
import shutil
import random
import math
import multiprocessing
from bs4 import BeautifulSoup #  conda install beautifulsoup4, coda install lxml
import os
import glob
# Out:
# Computer:  DESKTOP-F8TV69I

# %%
LUNA16_RAW_SRC_DIR ="G:/LungCancerPredict/original/luna_raw/"

LIDC_Annotations = "D:/jupyter-notebook/LungCancerPredict/LIDC_Annotations_3/"

# %%
if __name__ == "__main__":
    
     if True:
            
        process_lidc_annotations(agreement_threshold=)
# Out:
# 0 :  resources/luna16_annotations\157\158.xml
# 没有该病人CT图像
# 0 :  resources/luna16_annotations\157\159.xml
# Pos:  8  Neg:  37
# 1 :  resources/luna16_annotations\157\160.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\161.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\162.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\163.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\164.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\165.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\166.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\167.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\157\168.xml
# 没有该病人CT图像
# 1 :  resources/luna16_annotations\185\068.xml
# 1 :  resources/luna16_annotations\185\069.xml
# Pos:  12  Neg:  50
# 2 :  resources/luna16_annotations\185\070.xml
# 2 :  resources/luna16_annotations\185\071.xml
# Pos:  12  Neg:  75
# 3 :  resources/luna16_annotations\185\072.xml
# Pos:  25  Neg:  113
# 4 :  resources/luna16_annotations\185\073.xml
# 4 :  resources/luna16_annotations\185\074.xml
# Pos:  29  Neg:  186
# 5 :  resources/luna16_annotations\185\075.xml
# 5 :  resources/luna16_annotations\185\076.xml
# Pos:  33  Neg:  194
# 6 :  resources/luna16_annotations\185\077.xml
# 6 :  resources/luna16_annotations\185\078.xml
# Pos:  37  Neg:  231
# 7 :  resources/luna16_annotations\185\079.xml
# 7 :  resources/luna16_annotations\185\080.xml
# 7 :  resources/luna16_annotations\185\081.xml
# Pos:  41  Neg:  250
# 8 :  resources/luna16_annotations\185\082.xml
# Pos:  45  Neg:  270
# 9 :  resources/luna16_annotations\185\083.xml
# 9 :  resources/luna16_annotations\185\084.xml
# 9 :  resources/luna16_annotations\185\085.xml
# Pos:  45  Neg:  284
# 10 :  resources/luna16_annotations\185\086.xml
# Pos:  49  Neg:  294
# 11 :  resources/luna16_annotations\185\087.xml
# 11 :  resources/luna16_annotations\185\088.xml
# Pos:  61  Neg:  325
# 12 :  resources/luna16_annotations\185\089.xml
# Pos:  81  Neg:  338
# 13 :  resources/luna16_annotations\185\090.xml
# 13 :  resources/luna16_annotations\185\091.xml
# 13 :  resources/luna16_annotations\185\092.xml
# Pos:  89  Neg:  389
# 14 :  resources/luna16_annotations\185\093.xml
# 14 :  resources/luna16_annotations\185\094.xml
# Pos:  93  Neg:  389
# 15 :  resources/luna16_annotations\185\095.xml
# 15 :  resources/luna16_annotations\185\096.xml
# Pos:  97  Neg:  389
# 16 :  resources/luna16_annotations\185\097.xml
# 16 :  resources/luna16_annotations\185\098.xml
# Pos:  117  Neg:  401
# 17 :  resources/luna16_annotations\185\099.xml
# 17 :  resources/luna16_annotations\185\100.xml
# Pos:  121  Neg:  415
# 18 :  resources/luna16_annotations\185\101.xml
# 18 :  resources/luna16_annotations\185\102.xml
# Pos:  129  Neg:  417
# 19 :  resources/luna16_annotations\185\103.xml
# Pos:  129  Neg:  440
# 20 :  resources/luna16_annotations\185\104.xml
# 20 :  resources/luna16_annotations\185\105.xml
# 20 :  resources/luna16_annotations\185\106.xml
# Pos:  133  Neg:  462
# 21 :  resources/luna16_annotations\185\107.xml
# Pos:  137  Neg:  488
# 22 :  resources/luna16_annotations\185\108.xml
# 22 :  resources/luna16_annotations\185\109.xml
# 22 :  resources/luna16_annotations\185\110.xml
# Pos:  137  Neg:  507
# 23 :  resources/luna16_annotations\185\111.xml
# Pos:  141  Neg:  507
# 24 :  resources/luna16_annotations\185\112.xml
# 24 :  resources/luna16_annotations\185\113.xml
# Pos:  145  Neg:  519
# 25 :  resources/luna16_annotations\185\114.xml
# 25 :  resources/luna16_annotations\185\115.xml
# Pos:  145  Neg:  533
# 26 :  resources/luna16_annotations\185\116.xml
# 26 :  resources/luna16_annotations\185\117.xml
# Pos:  145  Neg:  542
# 27 :  resources/luna16_annotations\185\118.xml
# Pos:  153  Neg:  553
# 28 :  resources/luna16_annotations\185\119.xml
# 28 :  resources/luna16_annotations\185\120.xml
# 28 :  resources/luna16_annotations\185\121.xml
# Pos:  153  Neg:  575
# 29 :  resources/luna16_annotations\185\122.xml
# 29 :  resources/luna16_annotations\185\123.xml
# Pos:  153  Neg:  595
# 30 :  resources/luna16_annotations\185\124.xml
# 30 :  resources/luna16_annotations\185\125.xml
# Pos:  153  Neg:  612
# 31 :  resources/luna16_annotations\185\126.xml
# 31 :  resources/luna16_annotations\185\127.xml
# Pos:  165  Neg:  643
# 32 :  resources/luna16_annotations\185\128.xml
# 32 :  resources/luna16_annotations\185\129.xml
# Pos:  165  Neg:  653
# 33 :  resources/luna16_annotations\185\130.xml
# 33 :  resources/luna16_annotations\185\131.xml
# Pos:  169  Neg:  688
# 34 :  resources/luna16_annotations\185\132.xml
# 34 :  resources/luna16_annotations\185\133.xml
# Pos:  169  Neg:  700
# 35 :  resources/luna16_annotations\185\134.xml
# Pos:  169  Neg:  716
# 36 :  resources/luna16_annotations\185\135.xml
# 36 :  resources/luna16_annotations\185\136.xml
# Pos:  173  Neg:  720
# 37 :  resources/luna16_annotations\185\137.xml
# 37 :  resources/luna16_annotations\185\138.xml
# Pos:  177  Neg:  735
# 38 :  resources/luna16_annotations\185\139.xml
# 38 :  resources/luna16_annotations\185\140.xml
# Pos:  177  Neg:  752
# 39 :  resources/luna16_annotations\185\141.xml
# 39 :  resources/luna16_annotations\185\142.xml
# 39 :  resources/luna16_annotations\185\143.xml
# Pos:  197  Neg:  771
# 40 :  resources/luna16_annotations\185\144.xml
# Pos:  201  Neg:  779
# 41 :  resources/luna16_annotations\185\145.xml
# 41 :  resources/luna16_annotations\185\146.xml
# 41 :  resources/luna16_annotations\185\147.xml
# Pos:  205  Neg:  790
# 42 :  resources/luna16_annotations\185\148.xml
# 42 :  resources/luna16_annotations\185\149.xml
# Pos:  213  Neg:  793
# 43 :  resources/luna16_annotations\185\150.xml
# Pos:  217  Neg:  812
# 44 :  resources/luna16_annotations\185\151.xml
# 44 :  resources/luna16_annotations\185\152.xml
# Pos:  229  Neg:  817
# 45 :  resources/luna16_annotations\185\153.xml
# 45 :  resources/luna16_annotations\185\154.xml
# Pos:  253  Neg:  835
# 46 :  resources/luna16_annotations\185\155.xml
# 46 :  resources/luna16_annotations\185\156.xml
# Pos:  257  Neg:  847
# 47 :  resources/luna16_annotations\185\157.xml
# 47 :  resources/luna16_annotations\185\158.xml
# 47 :  resources/luna16_annotations\185\159.xml
# Pos:  261  Neg:  853
# 48 :  resources/luna16_annotations\185\160.xml
# 48 :  resources/luna16_annotations\185\161.xml
# Pos:  261  Neg:  911
# 49 :  resources/luna16_annotations\185\162.xml
# 49 :  resources/luna16_annotations\185\163.xml
# Pos:  277  Neg:  958
# 50 :  resources/luna16_annotations\185\164.xml
# 50 :  resources/luna16_annotations\185\165.xml
# Pos:  281  Neg:  965
# 51 :  resources/luna16_annotations\185\166.xml
# 51 :  resources/luna16_annotations\185\167.xml
# Pos:  289  Neg:  975
# 52 :  resources/luna16_annotations\185\168.xml
# 52 :  resources/luna16_annotations\185\169.xml
# Pos:  295  Neg:  995
# 53 :  resources/luna16_annotations\185\170.xml
# 53 :  resources/luna16_annotations\185\171.xml
# Pos:  303  Neg:  1012
# 54 :  resources/luna16_annotations\185\172.xml
# Pos:  307  Neg:  1045
# 55 :  resources/luna16_annotations\185\173.xml
# 55 :  resources/luna16_annotations\185\174.xml
# Pos:  319  Neg:  1048
# 56 :  resources/luna16_annotations\185\175.xml
# 56 :  resources/luna16_annotations\185\176.xml
# 56 :  resources/luna16_annotations\185\177.xml
# Pos:  323  Neg:  1069
# 57 :  resources/luna16_annotations\185\178.xml
# Pos:  327  Neg:  1072
# 58 :  resources/luna16_annotations\185\179.xml
# 58 :  resources/luna16_annotations\185\180.xml
# 58 :  resources/luna16_annotations\185\181.xml
# 58 :  resources/luna16_annotations\185\182.xml
# 58 :  resources/luna16_annotations\185\183.xml
# 58 :  resources/luna16_annotations\185\184.xml
# 58 :  resources/luna16_annotations\185\185.xml
# 58 :  resources/luna16_annotations\185\186.xml
# 58 :  resources/luna16_annotations\185\187.xml
# 58 :  resources/luna16_annotations\185\188.xml
# Pos:  331  Neg:  1101
# 59 :  resources/luna16_annotations\185\189.xml
# 59 :  resources/luna16_annotations\185\190.xml
# Pos:  335  Neg:  1115
# 60 :  resources/luna16_annotations\185\191.xml
# Pos:  339  Neg:  1168
# 61 :  resources/luna16_annotations\185\192.xml
# 61 :  resources/luna16_annotations\185\193.xml
# 61 :  resources/luna16_annotations\185\194.xml
# Pos:  351  Neg:  1185
# 62 :  resources/luna16_annotations\185\195.xml
# Pos:  351  Neg:  1201
# 63 :  resources/luna16_annotations\185\196.xml
# 63 :  resources/luna16_annotations\185\197.xml
# Pos:  355  Neg:  1207
# 64 :  resources/luna16_annotations\185\198.xml
# 64 :  resources/luna16_annotations\185\199.xml
# Pos:  363  Neg:  1207
# 65 :  resources/luna16_annotations\185\200.xml
# 65 :  resources/luna16_annotations\185\201.xml
# Pos:  363  Neg:  1236
# 66 :  resources/luna16_annotations\185\202.xml
# 66 :  resources/luna16_annotations\185\203.xml
# Pos:  371  Neg:  1295
# 67 :  resources/luna16_annotations\185\204.xml
# 67 :  resources/luna16_annotations\185\205.xml
# Pos:  383  Neg:  1301
# 68 :  resources/luna16_annotations\185\206.xml
# 68 :  resources/luna16_annotations\185\207.xml
# 68 :  resources/luna16_annotations\185\208.xml
# Pos:  403  Neg:  1309
# 69 :  resources/luna16_annotations\185\209.xml
# 69 :  resources/luna16_annotations\185\210.xml
# Pos:  403  Neg:  1310
# 70 :  resources/luna16_annotations\185\211.xml
# 70 :  resources/luna16_annotations\185\212.xml
# Pos:  403  Neg:  1326
# 71 :  resources/luna16_annotations\185\213.xml
# 71 :  resources/luna16_annotations\185\214.xml
# 71 :  resources/luna16_annotations\185\215.xml
# Pos:  403  Neg:  1338
# 72 :  resources/luna16_annotations\185\216.xml
# Pos:  407  Neg:  1357
# 73 :  resources/luna16_annotations\185\217.xml
# 73 :  resources/luna16_annotations\185\218.xml
# Pos:  407  Neg:  1374
# 74 :  resources/luna16_annotations\185\219.xml
# 74 :  resources/luna16_annotations\185\220.xml
# Pos:  411  Neg:  1430
# 75 :  resources/luna16_annotations\185\221.xml
# 75 :  resources/luna16_annotations\185\222.xml
# 75 :  resources/luna16_annotations\185\223.xml
# Pos:  419  Neg:  1447
# 76 :  resources/luna16_annotations\185\224.xml
# Pos:  423  Neg:  1480
# 77 :  resources/luna16_annotations\185\225.xml
# 77 :  resources/luna16_annotations\185\226.xml
# 77 :  resources/luna16_annotations\185\227.xml
# 77 :  resources/luna16_annotations\185\228.xml
# Pos:  429  Neg:  1519
# 78 :  resources/luna16_annotations\185\229.xml
# 78 :  resources/luna16_annotations\185\230.xml
# 78 :  resources/luna16_annotations\185\231.xml
# Pos:  433  Neg:  1535
# 79 :  resources/luna16_annotations\185\232.xml
# 79 :  resources/luna16_annotations\185\233.xml
# Pos:  433  Neg:  1571
# 80 :  resources/luna16_annotations\185\234.xml
# Pos:  437  Neg:  1584
# 81 :  resources/luna16_annotations\185\235.xml
# 81 :  resources/luna16_annotations\185\236.xml
# Pos:  437  Neg:  1648
# 82 :  resources/luna16_annotations\185\237.xml
# 82 :  resources/luna16_annotations\185\238.xml
# 没有该病人CT图像
# 82 :  resources/luna16_annotations\185\239.xml
# 82 :  resources/luna16_annotations\185\240.xml
# 没有该病人CT图像
# 82 :  resources/luna16_annotations\185\241.xml
# 82 :  resources/luna16_annotations\185\242.xml
# 82 :  resources/luna16_annotations\185\243.xml
# Pos:  437  Neg:  1674
# 83 :  resources/luna16_annotations\185\244.xml
# 83 :  resources/luna16_annotations\185\245.xml
# Pos:  441  Neg:  1701
# 84 :  resources/luna16_annotations\185\246.xml
# Pos:  445  Neg:  1710
# 85 :  resources/luna16_annotations\185\247.xml
# 85 :  resources/luna16_annotations\185\248.xml
# Pos:  449  Neg:  1734
# 86 :  resources/luna16_annotations\185\249.xml
# 86 :  resources/luna16_annotations\185\250.xml
# 86 :  resources/luna16_annotations\185\251.xml
# Pos:  461  Neg:  1765
# 87 :  resources/luna16_annotations\185\252.xml
# Pos:  466  Neg:  1777
# 88 :  resources/luna16_annotations\185\253.xml
# Pos:  470  Neg:  1779
# 89 :  resources/luna16_annotations\185\254.xml
# 89 :  resources/luna16_annotations\185\255.xml
# Pos:  474  Neg:  1782
# 90 :  resources/luna16_annotations\185\256.xml
# 90 :  resources/luna16_annotations\185\257.xml
# Pos:  482  Neg:  1807
# 91 :  resources/luna16_annotations\185\258.xml
# 91 :  resources/luna16_annotations\185\259.xml
# Pos:  482  Neg:  1814
# 92 :  resources/luna16_annotations\185\260.xml
# 92 :  resources/luna16_annotations\185\261.xml
# 92 :  resources/luna16_annotations\185\262.xml
# Pos:  482  Neg:  1827
# 93 :  resources/luna16_annotations\185\263.xml
# 没有该病人CT图像
# 93 :  resources/luna16_annotations\185\264.xml
# 93 :  resources/luna16_annotations\185\265.xml
# 93 :  resources/luna16_annotations\185\266.xml
# Pos:  486  Neg:  1852
# 94 :  resources/luna16_annotations\185\267.xml
# 94 :  resources/luna16_annotations\185\268.xml
# Pos:  486  Neg:  1854
# 95 :  resources/luna16_annotations\185\269.xml
# 95 :  resources/luna16_annotations\185\270.xml
# Pos:  486  Neg:  1855
# 96 :  resources/luna16_annotations\185\271.xml
# 96 :  resources/luna16_annotations\185\272.xml
# 没有该病人CT图像
# 96 :  resources/luna16_annotations\185\273.xml
# 96 :  resources/luna16_annotations\185\274.xml
# 96 :  resources/luna16_annotations\185\275.xml
# 没有该病人CT图像
# 96 :  resources/luna16_annotations\185\276.xml
# 96 :  resources/luna16_annotations\185\277.xml
# Pos:  486  Neg:  1889
# 97 :  resources/luna16_annotations\185\278.xml
# Pos:  490  Neg:  2020
# 98 :  resources/luna16_annotations\185\279.xml
# 98 :  resources/luna16_annotations\185\280.xml
# 没有该病人CT图像
# 98 :  resources/luna16_annotations\185\281.xml
# 98 :  resources/luna16_annotations\185\282.xml
# Pos:  494  Neg:  2033
# 99 :  resources/luna16_annotations\185\283.xml
# 99 :  resources/luna16_annotations\185\284.xml
# 99 :  resources/luna16_annotations\185\285.xml
# Pos:  498  Neg:  2037
# 100 :  resources/luna16_annotations\185\286.xml
# 100 :  resources/luna16_annotations\185\287.xml
# Pos:  510  Neg:  2047
# 101 :  resources/luna16_annotations\185\288.xml
# Pos:  514  Neg:  2050
# 102 :  resources/luna16_annotations\185\289.xml
# 102 :  resources/luna16_annotations\185\290.xml
# 102 :  resources/luna16_annotations\185\291.xml
# Pos:  514  Neg:  2066
# 103 :  resources/luna16_annotations\185\292.xml
# 103 :  resources/luna16_annotations\185\293.xml
# Pos:  518  Neg:  2095
# 104 :  resources/luna16_annotations\185\294.xml
# 104 :  resources/luna16_annotations\185\295.xml
# 104 :  resources/luna16_annotations\185\296.xml
# Pos:  522  Neg:  2109
# 105 :  resources/luna16_annotations\185\297.xml
# 105 :  resources/luna16_annotations\185\298.xml
# 没有该病人CT图像
# 105 :  resources/luna16_annotations\185\299.xml
# Pos:  526  Neg:  2109
# 106 :  resources/luna16_annotations\186\000.xml
# Pos:  534  Neg:  2142
# 107 :  resources/luna16_annotations\186\001.xml
# 107 :  resources/luna16_annotations\186\002.xml
# 107 :  resources/luna16_annotations\186\003.xml
# Pos:  537  Neg:  2193
# 108 :  resources/luna16_annotations\186\004.xml
# Pos:  545  Neg:  2196
# 109 :  resources/luna16_annotations\186\005.xml
# 109 :  resources/luna16_annotations\186\006.xml
# Pos:  549  Neg:  2210
# 110 :  resources/luna16_annotations\186\007.xml
# Pos:  549  Neg:  2220
# 111 :  resources/luna16_annotations\186\008.xml
# 111 :  resources/luna16_annotations\186\009.xml
# Pos:  561  Neg:  2229
# 112 :  resources/luna16_annotations\186\010.xml
# 112 :  resources/luna16_annotations\186\011.xml
# Pos:  561  Neg:  2237
# 113 :  resources/luna16_annotations\186\012.xml
# Pos:  565  Neg:  2247
# 114 :  resources/luna16_annotations\186\013.xml
# 114 :  resources/luna16_annotations\186\014.xml
# 114 :  resources/luna16_annotations\186\015.xml
# Pos:  569  Neg:  2269
# 115 :  resources/luna16_annotations\186\016.xml
# 115 :  resources/luna16_annotations\186\017.xml
# Pos:  601  Neg:  2298
# 116 :  resources/luna16_annotations\186\018.xml
# 116 :  resources/luna16_annotations\186\019.xml
# Pos:  609  Neg:  2298
# 117 :  resources/luna16_annotations\186\020.xml
# 117 :  resources/luna16_annotations\186\021.xml
# Pos:  609  Neg:  2315
# 118 :  resources/luna16_annotations\186\022.xml
# 118 :  resources/luna16_annotations\186\023.xml
# 没有该病人CT图像
# 118 :  resources/luna16_annotations\186\024.xml
# Pos:  613  Neg:  2333
# 119 :  resources/luna16_annotations\186\025.xml
# 119 :  resources/luna16_annotations\186\026.xml
# 119 :  resources/luna16_annotations\186\027.xml
# 没有该病人CT图像
# 119 :  resources/luna16_annotations\186\028.xml
# Pos:  625  Neg:  2340
# 120 :  resources/luna16_annotations\186\029.xml
# 120 :  resources/luna16_annotations\186\030.xml
# 120 :  resources/luna16_annotations\186\031.xml
# Pos:  630  Neg:  2359
# 121 :  resources/luna16_annotations\186\032.xml
# 121 :  resources/luna16_annotations\186\033.xml
# 121 :  resources/luna16_annotations\186\034.xml
# Pos:  630  Neg:  2386
# 122 :  resources/luna16_annotations\186\035.xml
# Pos:  630  Neg:  2420
# 123 :  resources/luna16_annotations\186\036.xml
# 123 :  resources/luna16_annotations\186\037.xml
# 123 :  resources/luna16_annotations\186\038.xml
# Pos:  634  Neg:  2457
# 124 :  resources/luna16_annotations\186\039.xml
# Pos:  646  Neg:  2466
# 125 :  resources/luna16_annotations\186\040.xml
# 125 :  resources/luna16_annotations\186\041.xml
# 125 :  resources/luna16_annotations\186\042.xml
# Pos:  654  Neg:  2478
# 126 :  resources/luna16_annotations\186\043.xml
# 126 :  resources/luna16_annotations\186\044.xml
# Pos:  654  Neg:  2479
# 127 :  resources/luna16_annotations\186\045.xml
# 127 :  resources/luna16_annotations\186\046.xml
# Pos:  670  Neg:  2485
# 128 :  resources/luna16_annotations\186\047.xml
# 128 :  resources/luna16_annotations\186\048.xml
# Pos:  674  Neg:  2507
# 129 :  resources/luna16_annotations\186\049.xml
# 没有该病人CT图像
# 129 :  resources/luna16_annotations\186\050.xml
# 129 :  resources/luna16_annotations\186\051.xml
# 129 :  resources/luna16_annotations\186\052.xml
# Pos:  674  Neg:  2542
# 130 :  resources/luna16_annotations\186\053.xml
# 130 :  resources/luna16_annotations\186\054.xml
# Pos:  682  Neg:  2564
# 131 :  resources/luna16_annotations\186\055.xml
# 131 :  resources/luna16_annotations\186\056.xml
# Pos:  690  Neg:  2582
# 132 :  resources/luna16_annotations\186\057.xml
# 132 :  resources/luna16_annotations\186\058.xml
# 132 :  resources/luna16_annotations\186\059.xml
# 没有该病人CT图像
# 132 :  resources/luna16_annotations\186\060.xml
# 132 :  resources/luna16_annotations\186\061.xml
# Pos:  694  Neg:  2582
# 133 :  resources/luna16_annotations\186\062.xml
# 133 :  resources/luna16_annotations\186\063.xml
# Pos:  694  Neg:  2584
# 134 :  resources/luna16_annotations\186\064.xml
# 134 :  resources/luna16_annotations\186\065.xml
# Pos:  694  Neg:  2606
# 135 :  resources/luna16_annotations\186\066.xml
# 135 :  resources/luna16_annotations\186\067.xml
# 135 :  resources/luna16_annotations\186\068.xml
# 没有该病人CT图像
# 135 :  resources/luna16_annotations\186\069.xml
# 135 :  resources/luna16_annotations\186\070.xml
# Pos:  694  Neg:  2615
# 136 :  resources/luna16_annotations\186\071.xml
# Pos:  698  Neg:  2647
# 137 :  resources/luna16_annotations\186\072.xml
# 137 :  resources/luna16_annotations\186\073.xml
# 137 :  resources/luna16_annotations\186\074.xml
# Pos:  702  Neg:  2649
# 138 :  resources/luna16_annotations\186\075.xml
# 138 :  resources/luna16_annotations\186\076.xml
# Pos:  714  Neg:  2657
# 139 :  resources/luna16_annotations\186\077.xml
# 139 :  resources/luna16_annotations\186\078.xml
# Pos:  718  Neg:  2688
# 140 :  resources/luna16_annotations\186\079.xml
# Pos:  722  Neg:  2693
# 141 :  resources/luna16_annotations\186\080.xml
# 141 :  resources/luna16_annotations\186\081.xml
# Pos:  726  Neg:  2693
# 142 :  resources/luna16_annotations\186\082.xml
# 142 :  resources/luna16_annotations\186\083.xml
# 142 :  resources/luna16_annotations\186\084.xml
# Pos:  750  Neg:  2713
# 143 :  resources/luna16_annotations\186\085.xml
# 143 :  resources/luna16_annotations\186\086.xml
# Pos:  750  Neg:  2740
# 144 :  resources/luna16_annotations\186\087.xml
# 144 :  resources/luna16_annotations\186\088.xml
# Pos:  750  Neg:  2748
# 145 :  resources/luna16_annotations\186\089.xml
# 145 :  resources/luna16_annotations\186\090.xml
# Pos:  750  Neg:  2756
# 146 :  resources/luna16_annotations\186\091.xml
# Pos:  754  Neg:  2782
# 147 :  resources/luna16_annotations\186\092.xml
# 147 :  resources/luna16_annotations\186\093.xml
# Pos:  762  Neg:  2797
# 148 :  resources/luna16_annotations\186\094.xml
# 148 :  resources/luna16_annotations\186\095.xml
# 148 :  resources/luna16_annotations\186\096.xml
# Pos:  766  Neg:  2806
# 149 :  resources/luna16_annotations\186\097.xml
# Pos:  782  Neg:  2813
# 150 :  resources/luna16_annotations\186\098.xml
# 150 :  resources/luna16_annotations\186\099.xml
# Pos:  786  Neg:  2820
# 151 :  resources/luna16_annotations\186\100.xml
# 151 :  resources/luna16_annotations\186\101.xml
# 151 :  resources/luna16_annotations\186\102.xml
# Pos:  786  Neg:  2848
# 152 :  resources/luna16_annotations\186\103.xml
# Pos:  786  Neg:  2859
# 153 :  resources/luna16_annotations\186\104.xml
# 153 :  resources/luna16_annotations\186\105.xml
# 153 :  resources/luna16_annotations\186\106.xml
# Pos:  790  Neg:  2868
# 154 :  resources/luna16_annotations\186\107.xml
# Pos:  790  Neg:  2888
# 155 :  resources/luna16_annotations\186\108.xml
# 155 :  resources/luna16_annotations\186\109.xml
# Pos:  794  Neg:  2889
# 156 :  resources/luna16_annotations\186\110.xml
# 156 :  resources/luna16_annotations\186\111.xml
# Pos:  794  Neg:  2895
# 157 :  resources/luna16_annotations\186\112.xml
# 157 :  resources/luna16_annotations\186\113.xml
# Pos:  798  Neg:  2922
# 158 :  resources/luna16_annotations\186\114.xml
# 158 :  resources/luna16_annotations\186\115.xml
# 158 :  resources/luna16_annotations\186\116.xml
# Pos:  798  Neg:  2947
# 159 :  resources/luna16_annotations\186\117.xml
# Pos:  818  Neg:  2963
# 160 :  resources/luna16_annotations\186\118.xml
# 160 :  resources/luna16_annotations\186\119.xml
# Pos:  822  Neg:  2974
# 161 :  resources/luna16_annotations\186\120.xml
# Pos:  826  Neg:  2988
# 162 :  resources/luna16_annotations\186\121.xml
# 162 :  resources/luna16_annotations\186\122.xml
# 162 :  resources/luna16_annotations\186\123.xml
# Pos:  830  Neg:  3001
# 163 :  resources/luna16_annotations\186\124.xml
# Pos:  842  Neg:  3015
# 164 :  resources/luna16_annotations\186\125.xml
# 164 :  resources/luna16_annotations\186\126.xml
# 164 :  resources/luna16_annotations\186\127.xml
# Pos:  846  Neg:  3049
# 165 :  resources/luna16_annotations\186\128.xml
# 165 :  resources/luna16_annotations\186\129.xml
# Pos:  850  Neg:  3060
# 166 :  resources/luna16_annotations\186\130.xml
# Pos:  866  Neg:  3063
# 167 :  resources/luna16_annotations\186\131.xml
# Pos:  866  Neg:  3083
# 168 :  resources/luna16_annotations\186\132.xml
# 168 :  resources/luna16_annotations\186\133.xml
# 168 :  resources/luna16_annotations\186\134.xml
# Pos:  874  Neg:  3083
# 169 :  resources/luna16_annotations\186\135.xml
# Pos:  878  Neg:  3107
# 170 :  resources/luna16_annotations\186\136.xml
# 170 :  resources/luna16_annotations\186\137.xml
# Pos:  882  Neg:  3125
# 171 :  resources/luna16_annotations\186\138.xml
# 171 :  resources/luna16_annotations\186\139.xml
# 171 :  resources/luna16_annotations\186\140.xml
# Pos:  886  Neg:  3136
# 172 :  resources/luna16_annotations\186\141.xml
# 172 :  resources/luna16_annotations\186\142.xml
# Pos:  894  Neg:  3153
# 173 :  resources/luna16_annotations\186\143.xml
# Pos:  914  Neg:  3195
# 174 :  resources/luna16_annotations\186\144.xml
# 174 :  resources/luna16_annotations\186\145.xml
# 174 :  resources/luna16_annotations\186\146.xml
# Pos:  918  Neg:  3205
# 175 :  resources/luna16_annotations\186\147.xml
# Pos:  918  Neg:  3206
# 176 :  resources/luna16_annotations\186\148.xml
# 176 :  resources/luna16_annotations\186\149.xml
# Pos:  918  Neg:  3239
# 177 :  resources/luna16_annotations\186\150.xml
# 177 :  resources/luna16_annotations\186\151.xml
# Pos:  922  Neg:  3258
# 178 :  resources/luna16_annotations\186\152.xml
# 178 :  resources/luna16_annotations\186\153.xml
# Pos:  922  Neg:  3275
# 179 :  resources/luna16_annotations\186\154.xml
# 179 :  resources/luna16_annotations\186\155.xml
# Pos:  922  Neg:  3297
# 180 :  resources/luna16_annotations\186\156.xml
# 180 :  resources/luna16_annotations\186\157.xml
# Pos:  922  Neg:  3301
# 181 :  resources/luna16_annotations\186\158.xml
# 181 :  resources/luna16_annotations\186\159.xml
# 181 :  resources/luna16_annotations\186\160.xml
# Pos:  930  Neg:  3329
# 182 :  resources/luna16_annotations\186\161.xml
# Pos:  935  Neg:  3336
# 183 :  resources/luna16_annotations\186\162.xml
# 183 :  resources/luna16_annotations\186\163.xml
# 183 :  resources/luna16_annotations\186\164.xml
# Pos:  935  Neg:  3338
# 184 :  resources/luna16_annotations\186\165.xml
# Pos:  943  Neg:  3364
# 185 :  resources/luna16_annotations\186\166.xml
# 185 :  resources/luna16_annotations\186\167.xml
# Pos:  943  Neg:  3371
# 186 :  resources/luna16_annotations\186\168.xml
# Pos:  951  Neg:  3377
# 187 :  resources/luna16_annotations\186\169.xml
# 187 :  resources/luna16_annotations\186\170.xml
# 187 :  resources/luna16_annotations\186\171.xml
# Pos:  955  Neg:  3405
# 188 :  resources/luna16_annotations\186\172.xml
# 188 :  resources/luna16_annotations\186\173.xml
# Pos:  959  Neg:  3405
# 189 :  resources/luna16_annotations\186\174.xml
# 189 :  resources/luna16_annotations\186\175.xml
# Pos:  963  Neg:  3410
# 190 :  resources/luna16_annotations\186\176.xml
# 190 :  resources/luna16_annotations\186\177.xml
# Pos:  963  Neg:  3410
# 191 :  resources/luna16_annotations\186\178.xml
# 191 :  resources/luna16_annotations\186\179.xml
# Pos:  967  Neg:  3423
# 192 :  resources/luna16_annotations\186\180.xml
# 192 :  resources/luna16_annotations\186\181.xml
# Pos:  967  Neg:  3435
# 193 :  resources/luna16_annotations\186\182.xml
# 193 :  resources/luna16_annotations\186\183.xml
# Pos:  971  Neg:  3454
# 194 :  resources/luna16_annotations\186\184.xml
# Pos:  975  Neg:  3474
# 195 :  resources/luna16_annotations\186\185.xml
# 195 :  resources/luna16_annotations\186\186.xml
# Pos:  987  Neg:  3492
# 196 :  resources/luna16_annotations\186\187.xml
# 196 :  resources/luna16_annotations\186\188.xml
# Pos:  987  Neg:  3530
# 197 :  resources/luna16_annotations\186\189.xml
# 197 :  resources/luna16_annotations\186\190.xml
# 197 :  resources/luna16_annotations\186\191.xml
# Pos:  991  Neg:  3564
# 198 :  resources/luna16_annotations\186\192.xml
# 198 :  resources/luna16_annotations\186\193.xml
# Pos:  999  Neg:  3598
# 199 :  resources/luna16_annotations\186\194.xml
# 199 :  resources/luna16_annotations\186\195.xml
# Pos:  1003  Neg:  3607
# 200 :  resources/luna16_annotations\186\196.xml
# 200 :  resources/luna16_annotations\186\197.xml
# Pos:  1007  Neg:  3638
# 201 :  resources/luna16_annotations\186\198.xml
# 201 :  resources/luna16_annotations\186\199.xml
# Pos:  1011  Neg:  3672
# 202 :  resources/luna16_annotations\186\200.xml
# Pos:  1011  Neg:  3678
# 203 :  resources/luna16_annotations\186\201.xml
# 203 :  resources/luna16_annotations\186\202.xml
# 203 :  resources/luna16_annotations\186\203.xml
# Pos:  1011  Neg:  3694
# 204 :  resources/luna16_annotations\186\204.xml
# 204 :  resources/luna16_annotations\186\205.xml
# Pos:  1011  Neg:  3697
# 205 :  resources/luna16_annotations\186\206.xml
# Pos:  1015  Neg:  3717
# 206 :  resources/luna16_annotations\186\207.xml
# 206 :  resources/luna16_annotations\186\208.xml
# Pos:  1019  Neg:  3736
# 207 :  resources/luna16_annotations\186\209.xml
# 207 :  resources/luna16_annotations\186\210.xml
# Pos:  1035  Neg:  3739
# 208 :  resources/luna16_annotations\186\211.xml
# 208 :  resources/luna16_annotations\186\212.xml
# 208 :  resources/luna16_annotations\186\213.xml
# Pos:  1035  Neg:  3742
# 209 :  resources/luna16_annotations\186\214.xml
# Pos:  1035  Neg:  3746
# 210 :  resources/luna16_annotations\186\215.xml
# 210 :  resources/luna16_annotations\186\216.xml
# Pos:  1035  Neg:  3752
# 211 :  resources/luna16_annotations\186\217.xml
# Pos:  1035  Neg:  3765
# 212 :  resources/luna16_annotations\186\218.xml
# 212 :  resources/luna16_annotations\186\219.xml
# 212 :  resources/luna16_annotations\186\220.xml
# Pos:  1039  Neg:  3769
# 213 :  resources/luna16_annotations\186\221.xml
# 213 :  resources/luna16_annotations\186\222.xml
# Pos:  1043  Neg:  3775
# 214 :  resources/luna16_annotations\186\223.xml
# 214 :  resources/luna16_annotations\186\224.xml
# Pos:  1047  Neg:  3781
# 215 :  resources/luna16_annotations\186\225.xml
# Pos:  1055  Neg:  3790
# 216 :  resources/luna16_annotations\186\226.xml
# 216 :  resources/luna16_annotations\186\227.xml
# 216 :  resources/luna16_annotations\186\228.xml
# Pos:  1055  Neg:  3804
# 217 :  resources/luna16_annotations\186\229.xml
# Pos:  1059  Neg:  3816
# 218 :  resources/luna16_annotations\186\230.xml
# 218 :  resources/luna16_annotations\186\231.xml
# Pos:  1068  Neg:  3856
# 219 :  resources/luna16_annotations\186\232.xml
# 219 :  resources/luna16_annotations\186\233.xml
# Pos:  1072  Neg:  3858
# 220 :  resources/luna16_annotations\186\234.xml
# 220 :  resources/luna16_annotations\186\235.xml
# Pos:  1072  Neg:  3880
# 221 :  resources/luna16_annotations\186\236.xml
# 221 :  resources/luna16_annotations\186\237.xml
# Pos:  1080  Neg:  3881
# 222 :  resources/luna16_annotations\186\238.xml
# 222 :  resources/luna16_annotations\186\239.xml
# Pos:  1080  Neg:  3881
# 223 :  resources/luna16_annotations\186\240.xml
# 223 :  resources/luna16_annotations\186\241.xml
# 223 :  resources/luna16_annotations\186\242.xml
# Pos:  1084  Neg:  3888
# 224 :  resources/luna16_annotations\186\243.xml
# 224 :  resources/luna16_annotations\186\244.xml
# Pos:  1084  Neg:  3888
# 225 :  resources/luna16_annotations\186\245.xml
# 225 :  resources/luna16_annotations\186\246.xml
# Pos:  1084  Neg:  3893
# 226 :  resources/luna16_annotations\186\247.xml
# 226 :  resources/luna16_annotations\186\248.xml
# Pos:  1092  Neg:  3897
# 227 :  resources/luna16_annotations\186\249.xml
# Pos:  1100  Neg:  3912
# 228 :  resources/luna16_annotations\186\250.xml
# 228 :  resources/luna16_annotations\186\251.xml
# Pos:  1104  Neg:  3922
# 229 :  resources/luna16_annotations\186\252.xml
# 229 :  resources/luna16_annotations\186\253.xml
# 229 :  resources/luna16_annotations\186\254.xml
# Pos:  1109  Neg:  3943
# 230 :  resources/luna16_annotations\186\255.xml
# 230 :  resources/luna16_annotations\186\256.xml
# Pos:  1109  Neg:  3945
# 231 :  resources/luna16_annotations\186\257.xml
# 231 :  resources/luna16_annotations\186\258.xml
# Pos:  1113  Neg:  3953
# 232 :  resources/luna16_annotations\186\259.xml
# Pos:  1121  Neg:  3954
# 233 :  resources/luna16_annotations\186\260.xml
# 233 :  resources/luna16_annotations\186\261.xml
# Pos:  1121  Neg:  3966
# 234 :  resources/luna16_annotations\186\262.xml
# 234 :  resources/luna16_annotations\186\263.xml
# 234 :  resources/luna16_annotations\186\264.xml
# Pos:  1121  Neg:  3980
# 235 :  resources/luna16_annotations\186\265.xml
# 235 :  resources/luna16_annotations\186\266.xml
# Pos:  1129  Neg:  3999
# 236 :  resources/luna16_annotations\186\267.xml
# 236 :  resources/luna16_annotations\186\268.xml
# Pos:  1133  Neg:  4005
# 237 :  resources/luna16_annotations\186\269.xml
# 237 :  resources/luna16_annotations\186\270.xml
# Pos:  1141  Neg:  4031
# 238 :  resources/luna16_annotations\186\271.xml
# 238 :  resources/luna16_annotations\186\272.xml
# Pos:  1141  Neg:  4051
# 239 :  resources/luna16_annotations\186\273.xml
# Pos:  1145  Neg:  4052
# 240 :  resources/luna16_annotations\186\274.xml
# Pos:  1149  Neg:  4083
# 241 :  resources/luna16_annotations\186\275.xml
# 241 :  resources/luna16_annotations\186\276.xml
# Pos:  1157  Neg:  4101
# 242 :  resources/luna16_annotations\186\277.xml
# 242 :  resources/luna16_annotations\186\278.xml
# 242 :  resources/luna16_annotations\186\279.xml
# Pos:  1161  Neg:  4101
# 243 :  resources/luna16_annotations\186\280.xml
# 243 :  resources/luna16_annotations\186\281.xml
# Pos:  1161  Neg:  4119
# 244 :  resources/luna16_annotations\186\282.xml
# 244 :  resources/luna16_annotations\186\283.xml
# 没有该病人CT图像
# 244 :  resources/luna16_annotations\186\284.xml
# Pos:  1161  Neg:  4120
# 245 :  resources/luna16_annotations\186\285.xml
# 245 :  resources/luna16_annotations\186\286.xml
# 245 :  resources/luna16_annotations\186\287.xml
# Pos:  1161  Neg:  4142
# 246 :  resources/luna16_annotations\186\288.xml
# Pos:  1165  Neg:  4144
# 247 :  resources/luna16_annotations\186\289.xml
# 247 :  resources/luna16_annotations\186\290.xml
# 247 :  resources/luna16_annotations\186\291.xml
# Pos:  1169  Neg:  4150
# 248 :  resources/luna16_annotations\186\292.xml
# 248 :  resources/luna16_annotations\186\293.xml
# Pos:  1173  Neg:  4156
# 249 :  resources/luna16_annotations\186\294.xml
# Pos:  1177  Neg:  4171
# 250 :  resources/luna16_annotations\186\295.xml
# 250 :  resources/luna16_annotations\186\296.xml
# 250 :  resources/luna16_annotations\186\297.xml
# Pos:  1181  Neg:  4180
# 251 :  resources/luna16_annotations\186\298.xml
# Pos:  1181  Neg:  4183
# 252 :  resources/luna16_annotations\186\299.xml
# 252 :  resources/luna16_annotations\187\000.xml
# Pos:  1185  Neg:  4197
# 253 :  resources/luna16_annotations\187\001.xml
# 253 :  resources/luna16_annotations\187\002.xml
# 253 :  resources/luna16_annotations\187\003.xml
# Pos:  1189  Neg:  4205
# 254 :  resources/luna16_annotations\187\004.xml
# Pos:  1193  Neg:  4214
# 255 :  resources/luna16_annotations\187\005.xml
# 255 :  resources/luna16_annotations\187\006.xml
# 255 :  resources/luna16_annotations\187\007.xml
# Pos:  1193  Neg:  4225
# 256 :  resources/luna16_annotations\187\008.xml
# Pos:  1193  Neg:  4242
# 257 :  resources/luna16_annotations\187\009.xml
# 257 :  resources/luna16_annotations\187\010.xml
# 257 :  resources/luna16_annotations\187\011.xml
# Pos:  1197  Neg:  4245
# 258 :  resources/luna16_annotations\187\012.xml
# Pos:  1201  Neg:  4260
# 259 :  resources/luna16_annotations\187\013.xml
# 259 :  resources/luna16_annotations\187\014.xml
# Pos:  1205  Neg:  4263
# 260 :  resources/luna16_annotations\187\015.xml
# 260 :  resources/luna16_annotations\187\016.xml
# Pos:  1213  Neg:  4281
# 261 :  resources/luna16_annotations\187\017.xml
# 261 :  resources/luna16_annotations\187\018.xml
# 261 :  resources/luna16_annotations\187\019.xml
# Pos:  1217  Neg:  4298
# 262 :  resources/luna16_annotations\187\020.xml
# Pos:  1225  Neg:  4298
# 263 :  resources/luna16_annotations\187\021.xml
# 263 :  resources/luna16_annotations\187\022.xml
# 263 :  resources/luna16_annotations\187\023.xml
# Pos:  1229  Neg:  4299
# 264 :  resources/luna16_annotations\187\024.xml
# Pos:  1229  Neg:  4302
# 265 :  resources/luna16_annotations\187\025.xml
# 265 :  resources/luna16_annotations\187\026.xml
# Pos:  1229  Neg:  4311
# 266 :  resources/luna16_annotations\187\027.xml
# 266 :  resources/luna16_annotations\187\028.xml
# 266 :  resources/luna16_annotations\187\029.xml
# Pos:  1229  Neg:  4328
# 267 :  resources/luna16_annotations\187\030.xml
# Pos:  1229  Neg:  4361
# 268 :  resources/luna16_annotations\187\031.xml
# Pos:  1229  Neg:  4383
# 269 :  resources/luna16_annotations\187\032.xml
# Pos:  1229  Neg:  4393
# 270 :  resources/luna16_annotations\187\033.xml
# Pos:  1233  Neg:  4453
# 271 :  resources/luna16_annotations\187\034.xml
# Pos:  1233  Neg:  4462
# 272 :  resources/luna16_annotations\187\035.xml
# 没有该病人CT图像
# 272 :  resources/luna16_annotations\187\036.xml
# Pos:  1233  Neg:  4520
# 273 :  resources/luna16_annotations\187\037.xml
# Pos:  1249  Neg:  4534
# 274 :  resources/luna16_annotations\187\038.xml
# Pos:  1253  Neg:  4572
# 275 :  resources/luna16_annotations\187\039.xml
# Pos:  1265  Neg:  4580
# 276 :  resources/luna16_annotations\187\040.xml
# Pos:  1265  Neg:  4606
# 277 :  resources/luna16_annotations\187\041.xml
# Pos:  1265  Neg:  4629
# 278 :  resources/luna16_annotations\187\042.xml
# 没有该病人CT图像
# 278 :  resources/luna16_annotations\187\043.xml
# Pos:  1265  Neg:  4648
# 279 :  resources/luna16_annotations\187\044.xml
# !!!!Nodule: Nodule 001  has no charecteristics
# Pos:  1269  Neg:  4655
# 280 :  resources/luna16_annotations\187\045.xml
# Pos:  1269  Neg:  4686
# 281 :  resources/luna16_annotations\187\046.xml
# Pos:  1269  Neg:  4705
# 282 :  resources/luna16_annotations\187\047.xml
# Pos:  1273  Neg:  4731
# 283 :  resources/luna16_annotations\187\048.xml
# Pos:  1277  Neg:  4753
# 284 :  resources/luna16_annotations\187\049.xml
# 没有该病人CT图像
# 284 :  resources/luna16_annotations\187\050.xml
# Pos:  1281  Neg:  4759
# 285 :  resources/luna16_annotations\187\051.xml
# Pos:  1281  Neg:  4776
# 286 :  resources/luna16_annotations\187\052.xml
# Pos:  1285  Neg:  4787
# 287 :  resources/luna16_annotations\187\053.xml
# Pos:  1289  Neg:  4826
# 288 :  resources/luna16_annotations\187\054.xml
# 没有该病人CT图像
# 288 :  resources/luna16_annotations\187\055.xml
# 没有该病人CT图像
# 288 :  resources/luna16_annotations\187\056.xml
# Pos:  1289  Neg:  4838
# 289 :  resources/luna16_annotations\187\057.xml
# Pos:  1289  Neg:  4858
# 290 :  resources/luna16_annotations\187\058.xml
# Pos:  1289  Neg:  4890
# 291 :  resources/luna16_annotations\187\059.xml
# Pos:  1293  Neg:  4940
# 292 :  resources/luna16_annotations\187\060.xml
# Pos:  1293  Neg:  4974
# 293 :  resources/luna16_annotations\187\061.xml
# Pos:  1297  Neg:  5053
# 294 :  resources/luna16_annotations\187\062.xml
# Pos:  1297  Neg:  5101
# 295 :  resources/luna16_annotations\187\063.xml
# 没有该病人CT图像
# 295 :  resources/luna16_annotations\187\064.xml
# Pos:  1297  Neg:  5114
# 296 :  resources/luna16_annotations\187\065.xml
# Pos:  1301  Neg:  5155
# 297 :  resources/luna16_annotations\187\066.xml
# Pos:  1309  Neg:  5176
# 298 :  resources/luna16_annotations\187\067.xml
# Pos:  1309  Neg:  5184
# 299 :  resources/luna16_annotations\187\068.xml
# Pos:  1309  Neg:  5222
# 300 :  resources/luna16_annotations\187\069.xml
# Pos:  1309  Neg:  5238
# 301 :  resources/luna16_annotations\187\070.xml
# Pos:  1309  Neg:  5248
# 302 :  resources/luna16_annotations\187\071.xml
# Pos:  1309  Neg:  5272
# 303 :  resources/luna16_annotations\187\072.xml
# Pos:  1317  Neg:  5292
# 304 :  resources/luna16_annotations\187\073.xml
# Pos:  1321  Neg:  5317
# 305 :  resources/luna16_annotations\187\074.xml
# Pos:  1321  Neg:  5354
# 306 :  resources/luna16_annotations\187\075.xml
# 没有该病人CT图像
# 306 :  resources/luna16_annotations\187\076.xml
# Pos:  1321  Neg:  5370
# 307 :  resources/luna16_annotations\187\077.xml
# Pos:  1321  Neg:  5420
# 308 :  resources/luna16_annotations\187\078.xml
# 没有该病人CT图像
# 308 :  resources/luna16_annotations\187\079.xml
# Pos:  1325  Neg:  5429
# 309 :  resources/luna16_annotations\187\080.xml
# Pos:  1325  Neg:  5465
# 310 :  resources/luna16_annotations\187\081.xml
# Pos:  1330  Neg:  5472
# 311 :  resources/luna16_annotations\187\082.xml
# Pos:  1342  Neg:  5515
# 312 :  resources/luna16_annotations\187\083.xml
# Pos:  1342  Neg:  5531
# 313 :  resources/luna16_annotations\187\084.xml
# Pos:  1346  Neg:  5561
# 314 :  resources/luna16_annotations\187\085.xml
# Pos:  1350  Neg:  5578
# 315 :  resources/luna16_annotations\187\086.xml
# Pos:  1350  Neg:  5591
# 316 :  resources/luna16_annotations\187\087.xml
# 没有该病人CT图像
# 316 :  resources/luna16_annotations\187\088.xml
# 没有该病人CT图像
# 316 :  resources/luna16_annotations\187\089.xml
# Pos:  1354  Neg:  5597
# 317 :  resources/luna16_annotations\187\090.xml
# Pos:  1354  Neg:  5640
# 318 :  resources/luna16_annotations\187\091.xml
# Pos:  1358  Neg:  5678
# 319 :  resources/luna16_annotations\187\092.xml
# 没有该病人CT图像
# 319 :  resources/luna16_annotations\187\093.xml
# Pos:  1358  Neg:  5714
# 320 :  resources/luna16_annotations\187\094.xml
# Pos:  1362  Neg:  5725
# 321 :  resources/luna16_annotations\187\095.xml
# 没有该病人CT图像
# 321 :  resources/luna16_annotations\187\096.xml
# 没有该病人CT图像
# 321 :  resources/luna16_annotations\187\097.xml
# 没有该病人CT图像
# 321 :  resources/luna16_annotations\187\098.xml
# Pos:  1378  Neg:  5755
# 322 :  resources/luna16_annotations\187\099.xml
# Pos:  1378  Neg:  5765
# 323 :  resources/luna16_annotations\187\100.xml
# Pos:  1386  Neg:  5799
# 324 :  resources/luna16_annotations\187\101.xml
# 没有该病人CT图像
# 324 :  resources/luna16_annotations\187\102.xml
# 没有该病人CT图像
# 324 :  resources/luna16_annotations\187\103.xml
# Pos:  1386  Neg:  5840
# 325 :  resources/luna16_annotations\187\104.xml
# Pos:  1390  Neg:  5847
# 326 :  resources/luna16_annotations\187\105.xml
# Pos:  1394  Neg:  5858
# 327 :  resources/luna16_annotations\187\106.xml
# Pos:  1394  Neg:  5947
# 328 :  resources/luna16_annotations\187\107.xml
# 没有该病人CT图像
# 328 :  resources/luna16_annotations\187\108.xml
# 没有该病人CT图像
# 328 :  resources/luna16_annotations\187\109.xml
# 没有该病人CT图像
# 328 :  resources/luna16_annotations\187\110.xml
# Pos:  1394  Neg:  5953
# 329 :  resources/luna16_annotations\187\111.xml
# 没有该病人CT图像
# 329 :  resources/luna16_annotations\187\112.xml
# Pos:  1398  Neg:  5975
# 330 :  resources/luna16_annotations\187\113.xml
# Pos:  1398  Neg:  6016
# 331 :  resources/luna16_annotations\187\114.xml
# Pos:  1398  Neg:  6060
# 332 :  resources/luna16_annotations\187\115.xml
# Pos:  1402  Neg:  6067
# 333 :  resources/luna16_annotations\187\116.xml
# Pos:  1402  Neg:  6078
# 334 :  resources/luna16_annotations\187\117.xml
# Pos:  1402  Neg:  6088
# 335 :  resources/luna16_annotations\187\118.xml
# Pos:  1410  Neg:  6124
# 336 :  resources/luna16_annotations\187\119.xml
# Pos:  1414  Neg:  6143
# 337 :  resources/luna16_annotations\187\120.xml
# Pos:  1418  Neg:  6168
# 338 :  resources/luna16_annotations\187\121.xml
# 没有该病人CT图像
# 338 :  resources/luna16_annotations\187\122.xml
# 没有该病人CT图像
# 338 :  resources/luna16_annotations\187\123.xml
# Pos:  1422  Neg:  6196
# 339 :  resources/luna16_annotations\187\124.xml
# 没有该病人CT图像
# 339 :  resources/luna16_annotations\187\125.xml
# 没有该病人CT图像
# 339 :  resources/luna16_annotations\187\126.xml
# Pos:  1422  Neg:  6200
# 340 :  resources/luna16_annotations\187\127.xml
# Pos:  1422  Neg:  6211
# 341 :  resources/luna16_annotations\187\128.xml
# Pos:  1426  Neg:  6235
# 342 :  resources/luna16_annotations\187\129.xml
# Pos:  1434  Neg:  6253
# 343 :  resources/luna16_annotations\187\130.xml
# 没有该病人CT图像
# 343 :  resources/luna16_annotations\187\131.xml
# Pos:  1434  Neg:  6272
# 344 :  resources/luna16_annotations\187\132.xml
# 没有该病人CT图像
# 344 :  resources/luna16_annotations\187\133.xml
# 没有该病人CT图像
# 344 :  resources/luna16_annotations\187\134.xml
# Pos:  1434  Neg:  6280
# 345 :  resources/luna16_annotations\187\135.xml
# Pos:  1438  Neg:  6323
# 346 :  resources/luna16_annotations\187\136.xml
# Pos:  1438  Neg:  6339
# 347 :  resources/luna16_annotations\187\137.xml
# Pos:  1446  Neg:  6351
# 348 :  resources/luna16_annotations\187\138.xml
# 没有该病人CT图像
# 348 :  resources/luna16_annotations\187\139.xml
# 没有该病人CT图像
# 348 :  resources/luna16_annotations\187\140.xml
# Pos:  1446  Neg:  6358
# 349 :  resources/luna16_annotations\187\141.xml
# Pos:  1458  Neg:  6360
# 350 :  resources/luna16_annotations\187\142.xml
# Pos:  1458  Neg:  6362
# 351 :  resources/luna16_annotations\187\143.xml
# Pos:  1462  Neg:  6431
# 352 :  resources/luna16_annotations\187\144.xml
# Pos:  1462  Neg:  6435
# 353 :  resources/luna16_annotations\187\145.xml
# Pos:  1470  Neg:  6449
# 354 :  resources/luna16_annotations\187\146.xml
# Pos:  1474  Neg:  6450
# 355 :  resources/luna16_annotations\187\147.xml
# Pos:  1485  Neg:  6461
# 356 :  resources/luna16_annotations\187\148.xml
# Pos:  1489  Neg:  6510
# 357 :  resources/luna16_annotations\187\149.xml
# Pos:  1493  Neg:  6532
# 358 :  resources/luna16_annotations\187\150.xml
# Pos:  1501  Neg:  6580
# 359 :  resources/luna16_annotations\187\151.xml
# Pos:  1505  Neg:  6590
# 360 :  resources/luna16_annotations\187\152.xml
# Pos:  1509  Neg:  6626
# 361 :  resources/luna16_annotations\187\153.xml
# Pos:  1509  Neg:  6652
# 362 :  resources/luna16_annotations\187\154.xml
# Pos:  1509  Neg:  6685
# 363 :  resources/luna16_annotations\187\155.xml
# Pos:  1513  Neg:  6720
# 364 :  resources/luna16_annotations\187\156.xml
# Pos:  1513  Neg:  6762
# 365 :  resources/luna16_annotations\187\157.xml
# 没有该病人CT图像
# 365 :  resources/luna16_annotations\187\158.xml
# Pos:  1529  Neg:  6767
# 366 :  resources/luna16_annotations\187\159.xml
# Pos:  1529  Neg:  6806
# 367 :  resources/luna16_annotations\187\160.xml
# Pos:  1529  Neg:  6809
# 368 :  resources/luna16_annotations\187\161.xml
# 没有该病人CT图像
# 368 :  resources/luna16_annotations\187\162.xml
# Pos:  1533  Neg:  6822
# 369 :  resources/luna16_annotations\187\163.xml
# Pos:  1533  Neg:  6858
# 370 :  resources/luna16_annotations\187\164.xml
# 没有该病人CT图像
# 370 :  resources/luna16_annotations\187\165.xml
# Pos:  1533  Neg:  6902
# 371 :  resources/luna16_annotations\187\166.xml
# Pos:  1537  Neg:  6904
# 372 :  resources/luna16_annotations\187\167.xml
# Pos:  1537  Neg:  6934
# 373 :  resources/luna16_annotations\187\168.xml
# Pos:  1537  Neg:  6953
# 374 :  resources/luna16_annotations\187\169.xml
# 没有该病人CT图像
# 374 :  resources/luna16_annotations\187\170.xml
# Pos:  1541  Neg:  6960
# 375 :  resources/luna16_annotations\187\171.xml
# Pos:  1541  Neg:  6988
# 376 :  resources/luna16_annotations\187\172.xml
# Pos:  1545  Neg:  6997
# 377 :  resources/luna16_annotations\187\173.xml
# Pos:  1549  Neg:  7002
# 378 :  resources/luna16_annotations\187\174.xml
# Pos:  1549  Neg:  7025
# 379 :  resources/luna16_annotations\187\175.xml
# Pos:  1549  Neg:  7037
# 380 :  resources/luna16_annotations\187\176.xml
# Pos:  1557  Neg:  7041
# 381 :  resources/luna16_annotations\187\177.xml
# Pos:  1569  Neg:  7054
# 382 :  resources/luna16_annotations\187\178.xml
# 没有该病人CT图像
# 382 :  resources/luna16_annotations\187\179.xml
# 没有该病人CT图像
# 382 :  resources/luna16_annotations\187\180.xml
# Pos:  1581  Neg:  7066
# 383 :  resources/luna16_annotations\187\181.xml
# Pos:  1585  Neg:  7100
# 384 :  resources/luna16_annotations\187\182.xml
# 没有该病人CT图像
# 384 :  resources/luna16_annotations\187\183.xml
# Pos:  1593  Neg:  7135
# 385 :  resources/luna16_annotations\187\184.xml
# Pos:  1593  Neg:  7209
# 386 :  resources/luna16_annotations\187\185.xml
# 没有该病人CT图像
# 386 :  resources/luna16_annotations\187\186.xml
# 没有该病人CT图像
# 386 :  resources/luna16_annotations\187\187.xml
# Pos:  1597  Neg:  7254
# 387 :  resources/luna16_annotations\187\188.xml
# Pos:  1597  Neg:  7267
# 388 :  resources/luna16_annotations\187\189.xml
# Pos:  1597  Neg:  7281
# 389 :  resources/luna16_annotations\187\190.xml
# Pos:  1597  Neg:  7291
# 390 :  resources/luna16_annotations\187\191.xml
# !!!!Nodule: Nodule 002  has no charecteristics
# Pos:  1601  Neg:  7316
# 391 :  resources/luna16_annotations\187\192.xml
# Pos:  1613  Neg:  7342
# 392 :  resources/luna16_annotations\187\193.xml
# 没有该病人CT图像
# 392 :  resources/luna16_annotations\187\194.xml
# Pos:  1633  Neg:  7389
# 393 :  resources/luna16_annotations\187\195.xml
# Pos:  1637  Neg:  7389
# 394 :  resources/luna16_annotations\187\196.xml
# Pos:  1641  Neg:  7426
# 395 :  resources/luna16_annotations\187\197.xml
# Pos:  1645  Neg:  7441
# 396 :  resources/luna16_annotations\187\198.xml
# Pos:  1660  Neg:  7463
# 397 :  resources/luna16_annotations\187\199.xml
# Pos:  1660  Neg:  7472
# 398 :  resources/luna16_annotations\187\200.xml
# Pos:  1672  Neg:  7482
# 399 :  resources/luna16_annotations\187\201.xml
# Pos:  1672  Neg:  7497
# 400 :  resources/luna16_annotations\187\202.xml
# Pos:  1672  Neg:  7505
# 401 :  resources/luna16_annotations\187\203.xml
# Pos:  1672  Neg:  7511
# 402 :  resources/luna16_annotations\187\204.xml
# Pos:  1672  Neg:  7526
# 403 :  resources/luna16_annotations\187\205.xml
# Pos:  1680  Neg:  7536
# 404 :  resources/luna16_annotations\187\206.xml
# Pos:  1688  Neg:  7558
# 405 :  resources/luna16_annotations\187\207.xml
# Pos:  1696  Neg:  7603
# 406 :  resources/luna16_annotations\187\208.xml
# Pos:  1700  Neg:  7622
# 407 :  resources/luna16_annotations\187\209.xml
# Pos:  1700  Neg:  7648
# 408 :  resources/luna16_annotations\187\210.xml
# Pos:  1700  Neg:  7687
# 409 :  resources/luna16_annotations\187\211.xml
# Pos:  1704  Neg:  7717
# 410 :  resources/luna16_annotations\187\212.xml
# Pos:  1704  Neg:  7731
# 411 :  resources/luna16_annotations\187\213.xml
# Pos:  1712  Neg:  7767
# 412 :  resources/luna16_annotations\187\214.xml
# Pos:  1716  Neg:  7781
# 413 :  resources/luna16_annotations\187\215.xml
# Pos:  1716  Neg:  7813
# 414 :  resources/luna16_annotations\187\216.xml
# Pos:  1716  Neg:  7817
# 415 :  resources/luna16_annotations\187\217.xml
# Pos:  1724  Neg:  7834
# 416 :  resources/luna16_annotations\187\218.xml
# Pos:  1724  Neg:  7851
# 417 :  resources/luna16_annotations\187\219.xml
# 没有该病人CT图像
# 417 :  resources/luna16_annotations\187\220.xml
# Pos:  1744  Neg:  7875
# 418 :  resources/luna16_annotations\187\221.xml
# Pos:  1744  Neg:  7887
# 419 :  resources/luna16_annotations\187\222.xml
# Pos:  1744  Neg:  7904
# 420 :  resources/luna16_annotations\187\223.xml
# Pos:  1744  Neg:  7912
# 421 :  resources/luna16_annotations\187\224.xml
# Pos:  1748  Neg:  7951
# 422 :  resources/luna16_annotations\187\225.xml
# Pos:  1760  Neg:  7964
# 423 :  resources/luna16_annotations\187\226.xml
# Pos:  1760  Neg:  7987
# 424 :  resources/luna16_annotations\187\227.xml
# Pos:  1760  Neg:  7999
# 425 :  resources/luna16_annotations\187\228.xml
# 没有该病人CT图像
# 425 :  resources/luna16_annotations\187\229.xml
# 没有该病人CT图像
# 425 :  resources/luna16_annotations\187\230.xml
# Pos:  1768  Neg:  8038
# 426 :  resources/luna16_annotations\187\231.xml
# Pos:  1772  Neg:  8041
# 427 :  resources/luna16_annotations\187\232.xml
# Pos:  1776  Neg:  8071
# 428 :  resources/luna16_annotations\187\233.xml
# Pos:  1780  Neg:  8116
# 429 :  resources/luna16_annotations\187\234.xml
# Pos:  1796  Neg:  8132
# 430 :  resources/luna16_annotations\187\235.xml
# Pos:  1800  Neg:  8180
# 431 :  resources/luna16_annotations\187\236.xml
# Pos:  1812  Neg:  8250
# 432 :  resources/luna16_annotations\187\237.xml
# Pos:  1816  Neg:  8258
# 433 :  resources/luna16_annotations\187\238.xml
# Pos:  1816  Neg:  8280
# 434 :  resources/luna16_annotations\187\239.xml
# Pos:  1816  Neg:  8374
# 435 :  resources/luna16_annotations\187\240.xml
# Pos:  1816  Neg:  8374
# 436 :  resources/luna16_annotations\187\241.xml
# Pos:  1820  Neg:  8395
# 437 :  resources/luna16_annotations\187\242.xml
# ...
# Pos:  2576  Neg:  14592
# 700 :  resources/luna16_annotations\188\249.xml
# Pos:  2576  Neg:  14598
# 701 :  resources/luna16_annotations\188\250.xml
# 没有该病人CT图像
# 701 :  resources/luna16_annotations\188\251.xml
# Pos:  2580  Neg:  14604
# 702 :  resources/luna16_annotations\188\252.xml
# Pos:  2580  Neg:  14618
# 703 :  resources/luna16_annotations\188\253.xml
# Pos:  2580  Neg:  14639
# 704 :  resources/luna16_annotations\188\254.xml
# Pos:  2584  Neg:  14648
# 705 :  resources/luna16_annotations\188\255.xml
# Pos:  2592  Neg:  14666
# 706 :  resources/luna16_annotations\188\256.xml
# Pos:  2600  Neg:  14712
# 707 :  resources/luna16_annotations\188\257.xml
# Pos:  2600  Neg:  14719
# 708 :  resources/luna16_annotations\188\258.xml
# Pos:  2600  Neg:  14742
# 709 :  resources/luna16_annotations\188\259.xml
# Pos:  2600  Neg:  14749
# 710 :  resources/luna16_annotations\188\260.xml
# Pos:  2604  Neg:  14800
# 711 :  resources/luna16_annotations\188\261.xml
# Pos:  2604  Neg:  14816
# 712 :  resources/luna16_annotations\188\262.xml
# Pos:  2616  Neg:  14824
# 713 :  resources/luna16_annotations\188\263.xml
# Pos:  2616  Neg:  14840
# 714 :  resources/luna16_annotations\188\264.xml
# Pos:  2616  Neg:  14854
# 715 :  resources/luna16_annotations\188\265.xml
# Pos:  2616  Neg:  14857
# 716 :  resources/luna16_annotations\188\266.xml
# Pos:  2616  Neg:  14865
# 717 :  resources/luna16_annotations\188\267.xml
# Pos:  2628  Neg:  14905
# 718 :  resources/luna16_annotations\188\268.xml
# Pos:  2632  Neg:  14920
# 719 :  resources/luna16_annotations\188\269.xml
# Pos:  2636  Neg:  14987
# 720 :  resources/luna16_annotations\188\270.xml
# Pos:  2644  Neg:  15032
# 721 :  resources/luna16_annotations\188\271.xml
# Pos:  2644  Neg:  15077
# 722 :  resources/luna16_annotations\188\272.xml
# Pos:  2644  Neg:  15134
# 723 :  resources/luna16_annotations\188\273.xml
# Pos:  2644  Neg:  15167
# 724 :  resources/luna16_annotations\188\274.xml
# Pos:  2644  Neg:  15210
# 725 :  resources/luna16_annotations\188\275.xml
# Pos:  2644  Neg:  15234
# 726 :  resources/luna16_annotations\188\276.xml
# Pos:  2644  Neg:  15243
# 727 :  resources/luna16_annotations\188\277.xml
# Pos:  2648  Neg:  15245
# 728 :  resources/luna16_annotations\188\278.xml
# Pos:  2656  Neg:  15279
# 729 :  resources/luna16_annotations\188\279.xml
# Pos:  2656  Neg:  15325
# 730 :  resources/luna16_annotations\188\280.xml
# Pos:  2656  Neg:  15363
# 731 :  resources/luna16_annotations\188\281.xml
# Pos:  2656  Neg:  15370
# 732 :  resources/luna16_annotations\188\282.xml
# Pos:  2656  Neg:  15475
# 733 :  resources/luna16_annotations\188\283.xml
# Pos:  2664  Neg:  15486
# 734 :  resources/luna16_annotations\188\284.xml
# Pos:  2668  Neg:  15498
# 735 :  resources/luna16_annotations\188\285.xml
# Pos:  2668  Neg:  15522
# 736 :  resources/luna16_annotations\188\286.xml
# Pos:  2672  Neg:  15551
# 737 :  resources/luna16_annotations\188\287.xml
# Pos:  2672  Neg:  15561
# 738 :  resources/luna16_annotations\188\288.xml
# Pos:  2672  Neg:  15574
# 739 :  resources/luna16_annotations\188\289.xml
# Pos:  2672  Neg:  15587
# 740 :  resources/luna16_annotations\188\290.xml
# Pos:  2677  Neg:  15634
# 741 :  resources/luna16_annotations\188\291.xml
# Pos:  2681  Neg:  15638
# 742 :  resources/luna16_annotations\188\292.xml
# Pos:  2681  Neg:  15653
# 743 :  resources/luna16_annotations\188\293.xml
# 没有该病人CT图像
# 743 :  resources/luna16_annotations\188\294.xml
# Pos:  2685  Neg:  15681
# 744 :  resources/luna16_annotations\188\295.xml
# Pos:  2693  Neg:  15714
# 745 :  resources/luna16_annotations\188\296.xml
# Pos:  2697  Neg:  15731
# 746 :  resources/luna16_annotations\188\297.xml
# Pos:  2697  Neg:  15765
# 747 :  resources/luna16_annotations\188\298.xml
# Pos:  2701  Neg:  15783
# 748 :  resources/luna16_annotations\188\299.xml
# Pos:  2705  Neg:  15844
# 749 :  resources/luna16_annotations\189\000.xml
# Pos:  2705  Neg:  15847
# 750 :  resources/luna16_annotations\189\001.xml
# Pos:  2705  Neg:  15850
# 751 :  resources/luna16_annotations\189\002.xml
# Pos:  2709  Neg:  15862
# 752 :  resources/luna16_annotations\189\003.xml
# Pos:  2709  Neg:  15866
# 753 :  resources/luna16_annotations\189\004.xml
# Pos:  2713  Neg:  15876
# 754 :  resources/luna16_annotations\189\005.xml
# Pos:  2717  Neg:  15914
# 755 :  resources/luna16_annotations\189\006.xml
# Pos:  2721  Neg:  15924
# 756 :  resources/luna16_annotations\189\007.xml
# 没有该病人CT图像
# 756 :  resources/luna16_annotations\189\008.xml
# Pos:  2721  Neg:  15963
# 757 :  resources/luna16_annotations\189\009.xml
# Pos:  2725  Neg:  15970
# 758 :  resources/luna16_annotations\189\010.xml
# Pos:  2729  Neg:  15998
# 759 :  resources/luna16_annotations\189\011.xml
# Pos:  2733  Neg:  16029
# 760 :  resources/luna16_annotations\189\012.xml
# Pos:  2733  Neg:  16044
# 761 :  resources/luna16_annotations\189\013.xml
# Pos:  2733  Neg:  16087
# 762 :  resources/luna16_annotations\189\014.xml
# Pos:  2737  Neg:  16099
# 763 :  resources/luna16_annotations\189\015.xml
# Pos:  2737  Neg:  16124
# 764 :  resources/luna16_annotations\189\016.xml
# Pos:  2741  Neg:  16124
# 765 :  resources/luna16_annotations\189\017.xml
# Pos:  2749  Neg:  16167
# 766 :  resources/luna16_annotations\189\018.xml
# Pos:  2749  Neg:  16181
# 767 :  resources/luna16_annotations\189\019.xml
# Pos:  2749  Neg:  16222
# 768 :  resources/luna16_annotations\189\020.xml
# Pos:  2770  Neg:  16262
# 769 :  resources/luna16_annotations\189\021.xml
# Pos:  2770  Neg:  16277
# 770 :  resources/luna16_annotations\189\022.xml
# Pos:  2770  Neg:  16291
# 771 :  resources/luna16_annotations\189\023.xml
# Pos:  2770  Neg:  16298
# 772 :  resources/luna16_annotations\189\024.xml
# Pos:  2770  Neg:  16315
# 773 :  resources/luna16_annotations\189\025.xml
# Pos:  2770  Neg:  16335
# 774 :  resources/luna16_annotations\189\026.xml
# Pos:  2770  Neg:  16445
# 775 :  resources/luna16_annotations\189\027.xml
# Pos:  2770  Neg:  16446
# 776 :  resources/luna16_annotations\189\028.xml
# Pos:  2778  Neg:  16452
# 777 :  resources/luna16_annotations\189\029.xml
# Pos:  2786  Neg:  16458
# 778 :  resources/luna16_annotations\189\030.xml
# Pos:  2794  Neg:  16464
# 779 :  resources/luna16_annotations\189\031.xml
# Pos:  2802  Neg:  16470
# 780 :  resources/luna16_annotations\189\032.xml
# Pos:  2810  Neg:  16476
# 781 :  resources/luna16_annotations\189\033.xml
# Pos:  2818  Neg:  16482
# 782 :  resources/luna16_annotations\189\034.xml
# Pos:  2822  Neg:  16484
# 783 :  resources/luna16_annotations\189\035.xml
# Pos:  2838  Neg:  16493
# 784 :  resources/luna16_annotations\189\036.xml
# Pos:  2838  Neg:  16508
# 785 :  resources/luna16_annotations\189\037.xml
# 没有该病人CT图像
# 785 :  resources/luna16_annotations\189\038.xml
# Pos:  2842  Neg:  16521
# 786 :  resources/luna16_annotations\189\039.xml
# Pos:  2846  Neg:  16544
# 787 :  resources/luna16_annotations\189\040.xml
# Pos:  2867  Neg:  16607
# 788 :  resources/luna16_annotations\189\041.xml
# Pos:  2867  Neg:  16634
# 789 :  resources/luna16_annotations\189\042.xml
# Pos:  2871  Neg:  16642
# 790 :  resources/luna16_annotations\189\043.xml
# Pos:  2871  Neg:  16672
# 791 :  resources/luna16_annotations\189\044.xml
# Pos:  2875  Neg:  16695
# 792 :  resources/luna16_annotations\189\045.xml
# Pos:  2875  Neg:  16753
# 793 :  resources/luna16_annotations\189\046.xml
# Pos:  2875  Neg:  16764
# 794 :  resources/luna16_annotations\189\047.xml
# Pos:  2879  Neg:  16801
# 795 :  resources/luna16_annotations\189\048.xml
# Pos:  2879  Neg:  16840
# 796 :  resources/luna16_annotations\189\049.xml
# Pos:  2883  Neg:  16856
# 797 :  resources/luna16_annotations\189\050.xml
# Pos:  2883  Neg:  16872
# 798 :  resources/luna16_annotations\189\051.xml
# Pos:  2891  Neg:  16897
# 799 :  resources/luna16_annotations\189\052.xml
# Pos:  2891  Neg:  16899
# 800 :  resources/luna16_annotations\189\053.xml
# Pos:  2891  Neg:  16931
# 801 :  resources/luna16_annotations\189\054.xml
# Pos:  2891  Neg:  16941
# 802 :  resources/luna16_annotations\189\055.xml
# Pos:  2891  Neg:  16947
# 803 :  resources/luna16_annotations\189\056.xml
# Pos:  2891  Neg:  16961
# 804 :  resources/luna16_annotations\189\057.xml
# Pos:  2891  Neg:  16982
# 805 :  resources/luna16_annotations\189\058.xml
# Pos:  2895  Neg:  16993
# 806 :  resources/luna16_annotations\189\059.xml
# 没有该病人CT图像
# 806 :  resources/luna16_annotations\189\060.xml
# 没有该病人CT图像
# 806 :  resources/luna16_annotations\189\061.xml
# 没有该病人CT图像
# 806 :  resources/luna16_annotations\189\062.xml
# Pos:  2903  Neg:  17013
# 807 :  resources/luna16_annotations\189\063.xml
# Pos:  2903  Neg:  17024
# 808 :  resources/luna16_annotations\189\064.xml
# Pos:  2903  Neg:  17041
# 809 :  resources/luna16_annotations\189\065.xml
# Pos:  2903  Neg:  17073
# 810 :  resources/luna16_annotations\189\066.xml
# Pos:  2907  Neg:  17088
# 811 :  resources/luna16_annotations\189\067.xml
# Pos:  2907  Neg:  17154
# 812 :  resources/luna16_annotations\189\068.xml
# Pos:  2907  Neg:  17175
# 813 :  resources/luna16_annotations\189\069.xml
# 没有该病人CT图像
# 813 :  resources/luna16_annotations\189\070.xml
# Pos:  2911  Neg:  17200
# 814 :  resources/luna16_annotations\189\071.xml
# Pos:  2911  Neg:  17206
# 815 :  resources/luna16_annotations\189\072.xml
# Pos:  2911  Neg:  17227
# 816 :  resources/luna16_annotations\189\073.xml
# 没有该病人CT图像
# 816 :  resources/luna16_annotations\189\074.xml
# Pos:  2911  Neg:  17236
# 817 :  resources/luna16_annotations\189\075.xml
# Pos:  2915  Neg:  17258
# 818 :  resources/luna16_annotations\189\076.xml
# Pos:  2919  Neg:  17331
# 819 :  resources/luna16_annotations\189\077.xml
# Pos:  2923  Neg:  17360
# 820 :  resources/luna16_annotations\189\078.xml
# Pos:  2927  Neg:  17423
# 821 :  resources/luna16_annotations\189\079.xml
# Pos:  2927  Neg:  17451
# 822 :  resources/luna16_annotations\189\080.xml
# Pos:  2931  Neg:  17455
# 823 :  resources/luna16_annotations\189\081.xml
# Pos:  2935  Neg:  17470
# 824 :  resources/luna16_annotations\189\082.xml
# Pos:  2935  Neg:  17482
# 825 :  resources/luna16_annotations\189\083.xml
# Pos:  2939  Neg:  17494
# 826 :  resources/luna16_annotations\189\084.xml
# Pos:  2943  Neg:  17507
# 827 :  resources/luna16_annotations\189\085.xml
# Pos:  2943  Neg:  17533
# 828 :  resources/luna16_annotations\189\086.xml
# 没有该病人CT图像
# 828 :  resources/luna16_annotations\189\087.xml
# Pos:  2947  Neg:  17541
# 829 :  resources/luna16_annotations\189\088.xml
# Pos:  2947  Neg:  17579
# 830 :  resources/luna16_annotations\189\089.xml
# Pos:  2947  Neg:  17587
# 831 :  resources/luna16_annotations\189\090.xml
# Pos:  2951  Neg:  17611
# 832 :  resources/luna16_annotations\189\091.xml
# 没有该病人CT图像
# 832 :  resources/luna16_annotations\189\092.xml
# Pos:  2951  Neg:  17625
# 833 :  resources/luna16_annotations\189\093.xml
# Pos:  2955  Neg:  17633
# 834 :  resources/luna16_annotations\189\094.xml
# Pos:  2955  Neg:  17651
# 835 :  resources/luna16_annotations\189\095.xml
# Pos:  2955  Neg:  17674
# 836 :  resources/luna16_annotations\189\096.xml
# Pos:  2955  Neg:  17693
# 837 :  resources/luna16_annotations\189\097.xml
# 没有该病人CT图像
# 837 :  resources/luna16_annotations\189\098.xml
# Pos:  2959  Neg:  17716
# 838 :  resources/luna16_annotations\189\099.xml
# Pos:  2959  Neg:  17719
# 839 :  resources/luna16_annotations\189\100.xml
# Pos:  2959  Neg:  17733
# 840 :  resources/luna16_annotations\189\101.xml
# 没有该病人CT图像
# 840 :  resources/luna16_annotations\189\102.xml
# Pos:  2967  Neg:  17747
# 841 :  resources/luna16_annotations\189\103.xml
# 没有该病人CT图像
# 841 :  resources/luna16_annotations\189\104.xml
# 没有该病人CT图像
# 841 :  resources/luna16_annotations\189\105.xml
# Pos:  2975  Neg:  17797
# 842 :  resources/luna16_annotations\189\106.xml
# Pos:  2979  Neg:  17812
# 843 :  resources/luna16_annotations\189\107.xml
# Pos:  2979  Neg:  17829
# 844 :  resources/luna16_annotations\189\108.xml
# Pos:  2982  Neg:  17874
# 845 :  resources/luna16_annotations\189\109.xml
# Pos:  2992  Neg:  17901
# 846 :  resources/luna16_annotations\189\110.xml
# Pos:  2992  Neg:  17929
# 847 :  resources/luna16_annotations\189\111.xml
# Pos:  2996  Neg:  17941
# 848 :  resources/luna16_annotations\189\112.xml
# Pos:  3000  Neg:  17959
# 849 :  resources/luna16_annotations\189\113.xml
# Pos:  3004  Neg:  17963
# 850 :  resources/luna16_annotations\189\114.xml
# Pos:  3008  Neg:  17985
# 851 :  resources/luna16_annotations\189\115.xml
# Pos:  3012  Neg:  17999
# 852 :  resources/luna16_annotations\189\116.xml
# Pos:  3016  Neg:  18003
# 853 :  resources/luna16_annotations\189\117.xml
# Pos:  3016  Neg:  18003
# 854 :  resources/luna16_annotations\189\118.xml
# Pos:  3016  Neg:  18024
# 855 :  resources/luna16_annotations\189\119.xml
# 没有该病人CT图像
# 855 :  resources/luna16_annotations\189\120.xml
# Pos:  3016  Neg:  18027
# 856 :  resources/luna16_annotations\189\121.xml
# Pos:  3016  Neg:  18046
# 857 :  resources/luna16_annotations\189\122.xml
# Pos:  3020  Neg:  18079
# 858 :  resources/luna16_annotations\189\123.xml
# Pos:  3020  Neg:  18085
# 859 :  resources/luna16_annotations\189\124.xml
# Pos:  3044  Neg:  18101
# 860 :  resources/luna16_annotations\189\125.xml
# 没有该病人CT图像
# 860 :  resources/luna16_annotations\189\126.xml
# Pos:  3044  Neg:  18104
# 861 :  resources/luna16_annotations\189\127.xml
# Pos:  3044  Neg:  18126
# 862 :  resources/luna16_annotations\189\128.xml
# Pos:  3046  Neg:  18148
# 863 :  resources/luna16_annotations\189\129.xml
# Pos:  3050  Neg:  18151
# 864 :  resources/luna16_annotations\189\130.xml
# Pos:  3050  Neg:  18184
# 865 :  resources/luna16_annotations\189\131.xml
# Pos:  3050  Neg:  18211
# 866 :  resources/luna16_annotations\189\132.xml
# Pos:  3054  Neg:  18267
# 867 :  resources/luna16_annotations\189\133.xml
# Pos:  3054  Neg:  18273
# 868 :  resources/luna16_annotations\189\134.xml
# Pos:  3058  Neg:  18308
# 869 :  resources/luna16_annotations\189\135.xml
# Pos:  3058  Neg:  18338
# 870 :  resources/luna16_annotations\189\136.xml
# Pos:  3062  Neg:  18374
# 871 :  resources/luna16_annotations\189\137.xml
# Pos:  3070  Neg:  18380
# 872 :  resources/luna16_annotations\189\138.xml
# 没有该病人CT图像
# 872 :  resources/luna16_annotations\189\139.xml
# Pos:  3082  Neg:  18413
# 873 :  resources/luna16_annotations\189\140.xml
# Pos:  3082  Neg:  18455
# 874 :  resources/luna16_annotations\189\141.xml
# Pos:  3082  Neg:  18483
# 875 :  resources/luna16_annotations\189\142.xml
# Pos:  3082  Neg:  18484
# 876 :  resources/luna16_annotations\189\143.xml
# Pos:  3082  Neg:  18486
# 877 :  resources/luna16_annotations\189\144.xml
# Pos:  3082  Neg:  18515
# 878 :  resources/luna16_annotations\189\145.xml
# Pos:  3082  Neg:  18523
# 879 :  resources/luna16_annotations\189\146.xml
# Pos:  3082  Neg:  18536
# 880 :  resources/luna16_annotations\189\147.xml
# Pos:  3082  Neg:  18555
# 881 :  resources/luna16_annotations\189\148.xml
# Pos:  3082  Neg:  18613
# 882 :  resources/luna16_annotations\189\149.xml
# Pos:  3086  Neg:  18630
# 883 :  resources/luna16_annotations\189\150.xml
# Pos:  3090  Neg:  18638
# 884 :  resources/luna16_annotations\189\151.xml
# Pos:  3094  Neg:  18679
# 885 :  resources/luna16_annotations\189\152.xml
# Pos:  3098  Neg:  18733
# 886 :  resources/luna16_annotations\189\153.xml
# Pos:  3098  Neg:  18783
# 887 :  resources/luna16_annotations\189\154.xml
# Pos:  3102  Neg:  18797
# 888 :  resources/luna16_annotations\189\155.xml
# Pos:  3122  Neg:  18834
# 889 :  resources/luna16_annotations\189\156.xml
# Pos:  3122  Neg:  18864
# 890 :  resources/luna16_annotations\189\157.xml
# Pos:  3122  Neg:  18869
# 891 :  resources/luna16_annotations\189\158.xml
# Pos:  3122  Neg:  18884
# 892 :  resources/luna16_annotations\189\159.xml
# Pos:  3130  Neg:  18894
# 893 :  resources/luna16_annotations\189\160.xml
# Pos:  3130  Neg:  18920
# 894 :  resources/luna16_annotations\189\161.xml
# Pos:  3158  Neg:  18926
# 895 :  resources/luna16_annotations\189\162.xml
# Pos:  3162  Neg:  18947
# 896 :  resources/luna16_annotations\189\163.xml
# Pos:  3162  Neg:  18980
# 897 :  resources/luna16_annotations\189\164.xml
# Pos:  3162  Neg:  19010
# 898 :  resources/luna16_annotations\189\165.xml
# Pos:  3166  Neg:  19030
# 899 :  resources/luna16_annotations\189\166.xml
# Pos:  3170  Neg:  19040
# 900 :  resources/luna16_annotations\189\167.xml
# Pos:  3174  Neg:  19072
# 901 :  resources/luna16_annotations\189\168.xml
# 没有该病人CT图像
# 901 :  resources/luna16_annotations\189\169.xml
# Pos:  3182  Neg:  19083
# 902 :  resources/luna16_annotations\189\170.xml
# 没有该病人CT图像
# 902 :  resources/luna16_annotations\189\171.xml
# Pos:  3182  Neg:  19109
# 903 :  resources/luna16_annotations\189\172.xml
# Pos:  3182  Neg:  19123
# 904 :  resources/luna16_annotations\189\173.xml
# 没有该病人CT图像
# 904 :  resources/luna16_annotations\189\174.xml
# 没有该病人CT图像

# %%
def process_lidc_annotations(agreement_threshold=0):
    
    file_no = 0
    pos_count = 0
    neg_count = 0
    all_lines = []
    used_files = []
    
    for anno_dir in [d for d in glob.glob("resources/luna16_annotations/*") if os.path.isdir(d)]:

        xml_paths = glob.glob(anno_dir + "/*.xml")
        
        for xml_path in xml_paths:
            
            print(file_no, ": ",  xml_path)
            
            pos, neg, extended = load_lidc_xml(xml_path=xml_path, agreement_threshold=agreement_threshold)
            
            if pos is not None:
                
                used_files.append(xml_path)
                pos_count += len(pos)
                neg_count += len(neg)
                print("Pos: ", pos_count, " Neg: ", neg_count)
                file_no += 1
                all_lines += extended

    df_annos = pandas.DataFrame(all_lines, columns=["patient_id", "anno_index", "coord_x", "coord_y", "coord_z", "diameter", "malscore", "sphericiy", "margin", "spiculation", "texture", "calcification", "internal_structure", "lobulation", "subtlety"])
    df_annos.to_csv(LIDC_Annotations + "lidc_annotations.csv", index=False)

# %%
def load_lidc_xml(xml_path, agreement_threshold=0, save_nodules=False):
    
    pos_lines = []
    neg_lines = []
    extended_lines = []
    
    with open(xml_path, 'r') as xml_file:
        markup = xml_file.read()
    
    xml = BeautifulSoup(markup, features="xml")
    
    if xml.LidcReadMessage is None:
        return None, None, None
    
    patient_id = xml.LidcReadMessage.ResponseHeader.SeriesInstanceUid.text

    src_path = find_mhd_file(patient_id)
    
    if src_path is None:
        print("没有该病人CT图像")
        return None, None, None
    
    itk_img = SimpleITK.ReadImage(src_path)
    img_array = SimpleITK.GetArrayFromImage(itk_img)
    num_z, height, width = img_array.shape        #heightXwidth constitute the transverse plane
    origin = numpy.array(itk_img.GetOrigin())      # x,y,z  Origin in world coordinates (mm)
    spacing = numpy.array(itk_img.GetSpacing())    # spacing of voxels in world coor. (mm)
    rescale = spacing / settings.TARGET_VOXEL_MM
    
    reading_sessions = xml.LidcReadMessage.find_all("readingSession")
    
    #print(len(reading_sessions)) 放射学家的数量

    for reading_session in reading_sessions:

        nodules = reading_session.find_all("unblindedReadNodule")
        
        for nodule in nodules:
            
            nodule_id = nodule.noduleID.text
            rois = nodule.find_all("roi")
            
            x_min = y_min = z_min = 999999
            x_max = y_max = z_max = -999999
            
            if len(rois) < 2:
                continue
        
            for roi in rois:
                
                z_pos = float(roi.imageZposition.text)
                z_min = min(z_min, z_pos)
                z_max = max(z_max, z_pos)
                
                edge_maps = roi.find_all("edgeMap")
   
                for edge_map in edge_maps:
        
                    x = int(edge_map.xCoord.text)
                    y = int(edge_map.yCoord.text)
                    x_min = min(x_min, x)
                    y_min = min(y_min, y)
                    x_max = max(x_max, x)
                    y_max = max(y_max, y)
                    
                if x_max == x_min:
                    continue
                if y_max == y_min:
                    continue

            x_diameter = x_max - x_min
            x_center = x_min + x_diameter / 2
            y_diameter = y_max - y_min
            y_center = y_min + y_diameter / 2
            z_diameter = z_max - z_min
            z_center = z_min + z_diameter / 2
            z_center -= origin[2]
            z_center /= spacing[2]

            x_center_perc = round(x_center / img_array.shape[2], 4)
            y_center_perc = round(y_center / img_array.shape[1], 4)
            z_center_perc = round(z_center / img_array.shape[0], 4)
            
            diameter = max(x_diameter , y_diameter)
            diameter_perc = round(max(x_diameter / img_array.shape[2], y_diameter / img_array.shape[1]), 4)

            if nodule.characteristics is None:
                print("!!!!Nodule:", nodule_id, " has no charecteristics")
                continue
            if nodule.characteristics.malignancy is None:
                print("!!!!Nodule:", nodule_id, " has no malignacy")
                continue
         
            malignacy = nodule.characteristics.malignancy.text
            sphericiy = nodule.characteristics.sphericity.text
            margin = nodule.characteristics.margin.text
            spiculation = nodule.characteristics.spiculation.text
            texture = nodule.characteristics.texture.text
            calcification = nodule.characteristics.calcification.text
            internal_structure = nodule.characteristics.internalStructure.text
            lobulation = nodule.characteristics.lobulation.text
            subtlety = nodule.characteristics.subtlety.text

            #line = [nodule_id, x_center_perc, y_center_perc, z_center_perc, diameter_perc, malignacy]  
            line = [nodule_id, x_center_perc, y_center_perc, z_center_perc, diameter_perc, malignacy, sphericiy, margin, spiculation, texture, calcification, internal_structure, lobulation, subtlety]  
            extended_line = [ patient_id, nodule_id, x_center_perc, y_center_perc, z_center_perc, diameter_perc, malignacy, sphericiy, margin, spiculation, texture, calcification, internal_structure, lobulation, subtlety ]
                                                                                                   
            pos_lines.append(line)
            extended_lines.append(extended_line)
    

        nonNodules = reading_session.find_all("nonNodule")
        
        for nonNodule in nonNodules:
            
            z_center = float(nonNodule.imageZposition.text)
            z_center -= origin[2]
            z_center /= spacing[2]
            x_center = int(nonNodule.locus.xCoord.text)
            y_center = int(nonNodule.locus.yCoord.text)
            nodule_id = nonNodule.nonNoduleID.text
            x_center_perc = round(x_center / img_array.shape[2], 4)
            y_center_perc = round(y_center / img_array.shape[1], 4)
            z_center_perc = round(z_center / img_array.shape[0], 4)
            diameter_perc = round(max(6 / img_array.shape[2], 6 / img_array.shape[1]), 4)
    
            line = [nodule_id, x_center_perc, y_center_perc, z_center_perc, diameter_perc, 0]
            neg_lines.append(line)
    
    
    if agreement_threshold > 1:
        
        filtered_lines = []
        for pos_line1 in pos_lines:
            id1 = pos_line1[0]
            x1 = pos_line1[1]
            y1 = pos_line1[2]
            z1 = pos_line1[3]
            d1 = pos_line1[4]
            overlaps = 0
            for pos_line2 in pos_lines:
                id2 = pos_line2[0]
                if id1 == id2:
                    continue
                x2 = pos_line2[1]
                y2 = pos_line2[2]
                z2 = pos_line2[3]
                d2 = pos_line1[4]
                dist = math.sqrt(math.pow(x1 - x2, 2) + math.pow(y1 - y2, 2) + math.pow(z1 - z2, 2))
                if dist < d1 or dist < d2:
                    overlaps += 1
                    
            if overlaps >= agreement_threshold:
                filtered_lines.append(pos_line1)

        pos_lines = filtered_lines
        
    df_annos = pandas.DataFrame(pos_lines, columns=["anno_index", "coord_x", "coord_y", "coord_z", "diameter", "malscore" ,  "sphericiy", "margin", "spiculation", "texture", "calcification", "internal_structure", "lobulation", "subtlety"])
    df_annos.to_csv(LIDC_Annotations + "_labels/" + patient_id + "_annos_pos_lidc.csv", index=False)
    df_neg_annos = pandas.DataFrame(neg_lines, columns=["anno_index", "coord_x", "coord_y", "coord_z", "diameter", "malscore"])
    df_neg_annos.to_csv(LIDC_Annotations + "_labels/" + patient_id + "_annos_neg_lidc.csv", index=False)
      
    return pos_lines, neg_lines, extended_lines

# %%
def find_mhd_file(patient_id):
    for subject_no in range(settings.LUNA_SUBSET_START_INDEX, 10):
        src_dir = LUNA16_RAW_SRC_DIR  + "subset" + str(subject_no) + "/"
        for src_path in glob.glob(src_dir + "*.mhd"):
            if patient_id in src_path:
                return src_path
    return None
