# %%
import settings
import helpers
import sys
import os
import glob
import random
import pandas
import ntpath
import cv2
import numpy
from typing import List, Tuple
from keras.optimizers import Adam, SGD
from keras.layers import Input, Convolution2D, MaxPooling2D, UpSampling2D, merge, Convolution3D, MaxPooling3D, UpSampling3D, LeakyReLU, BatchNormalization, Flatten, Dense, Dropout, ZeroPadding3D, AveragePooling3D, Activation
from keras.models import Model, load_model, model_from_json
from keras.metrics import binary_accuracy, binary_crossentropy, mean_squared_error, mean_absolute_error
from keras import backend as K
from keras.callbacks import ModelCheckpoint, Callback, LearningRateScheduler
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
import math


# limit memory usage..
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
import Nodule_Detector_CNN
# Out:
# Computer:  DESKTOP-F8TV69I
# Using TensorFlow backend.

# %%
K.set_image_dim_ordering("tf")
CUBE_SIZE = Nodule_Detector_CNN.CUBE_SIZE
MEAN_PIXEL_VALUE = settings.MEAN_PIXEL_VALUE_NODULE
NEGS_PER_POS = 20
P_TH = 0.5

PREDICT_STEP = 12
USE_DROPOUT = False

# %% [markdown]
# # 该脚本对luna16数据集进行扫描

# %% [markdown]
# # 有时间可以尝试一下对原始数据旋转之后再scan

# %%
if __name__ == "__main__":

    if True:
        
        for magnification in [2]:  
            
            predict_cubes("models/nodule_detector_v1/luna16_full_CNN_v1-0.0001.hd5", magnification=magnification, ext_name="luna16_fs")
# Out:
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:121: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(pool_size=(2, 1, 1), padding="same", strides=(2, 1, 1))`
#   x = AveragePooling3D(pool_size=(2, 1, 1), strides=(2, 1, 1), border_mode="same")(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:122: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(64, (3, 3, 3), name="conv1", strides=(1, 1, 1), padding="same", activation="relu")`
#   x = Convolution3D(64, 3, 3, 3, activation='relu', border_mode='same', name='conv1', subsample=(1, 1, 1))(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:123: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(name="pool1", pool_size=(1, 2, 2), padding="valid", strides=(1, 2, 2))`
#   x = MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), border_mode='valid', name='pool1')(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:126: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(128, (3, 3, 3), name="conv2", strides=(1, 1, 1), padding="same", activation="relu")`
#   x = Convolution3D(128, 3, 3, 3, activation='relu', border_mode='same', name='conv2', subsample=(1, 1, 1))(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:127: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(name="pool2", pool_size=(2, 2, 2), padding="valid", strides=(2, 2, 2))`
#   x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool2')(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:132: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(256, (3, 3, 3), name="conv3a", strides=(1, 1, 1), padding="same", activation="relu")`
#   x = Convolution3D(256, 3, 3, 3, activation='relu', border_mode='same', name='conv3a', subsample=(1, 1, 1))(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:133: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(256, (3, 3, 3), name="conv3b", strides=(1, 1, 1), padding="same", activation="relu")`
#   x = Convolution3D(256, 3, 3, 3, activation='relu', border_mode='same', name='conv3b', subsample=(1, 1, 1))(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:134: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(name="pool3", pool_size=(2, 2, 2), padding="valid", strides=(2, 2, 2))`
#   x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool3')(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:139: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), name="conv4a", strides=(1, 1, 1), padding="same", activation="relu")`
#   x = Convolution3D(512, 3, 3, 3, activation='relu', border_mode='same', name='conv4a', subsample=(1, 1, 1))(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:140: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), name="conv4b", strides=(1, 1, 1), padding="same", activation="relu")`
#   x = Convolution3D(512, 3, 3, 3, activation='relu', border_mode='same', name='conv4b', subsample=(1, 1, 1),)(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:141: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(name="pool4", pool_size=(2, 2, 2), padding="valid", strides=(2, 2, 2))`
#   x = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), border_mode='valid', name='pool4')(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:146: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(64, (2, 2, 2), name="last_64", activation="relu")`
#   last64 = Convolution3D(64, 2, 2, 2, activation="relu", name="last_64")(x)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:147: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(1, (1, 1, 1), name="out_class_last", activation="sigmoid")`
#   out_class = Convolution3D(1, 1, 1, 1, activation="sigmoid", name="out_class_last")(last64)
# D:\jupyter-notebook\LungCancerPredict\Nodule_Detector_CNN.py:154: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ou...)`
#   model = Model(input=inputs, output=out_class)
# ____________________________________________________________________________________________________________________________________________
# Layer (type)                                                   Output Shape                                            Param #
# ============================================================================================================================================
# input_1 (InputLayer)                                           (None, 32, 32, 32, 1)                                   0
# ____________________________________________________________________________________________________________________________________________
# average_pooling3d_1 (AveragePooling3D)                         (None, 16, 32, 32, 1)                                   0
# ____________________________________________________________________________________________________________________________________________
# conv1 (Conv3D)                                                 (None, 16, 32, 32, 64)                                  1792
# ____________________________________________________________________________________________________________________________________________
# pool1 (MaxPooling3D)                                           (None, 16, 16, 16, 64)                                  0
# ____________________________________________________________________________________________________________________________________________
# conv2 (Conv3D)                                                 (None, 16, 16, 16, 128)                                 221312
# ____________________________________________________________________________________________________________________________________________
# pool2 (MaxPooling3D)                                           (None, 8, 8, 8, 128)                                    0
# ____________________________________________________________________________________________________________________________________________
# conv3a (Conv3D)                                                (None, 8, 8, 8, 256)                                    884992
# ____________________________________________________________________________________________________________________________________________
# conv3b (Conv3D)                                                (None, 8, 8, 8, 256)                                    1769728
# ____________________________________________________________________________________________________________________________________________
# pool3 (MaxPooling3D)                                           (None, 4, 4, 4, 256)                                    0
# ____________________________________________________________________________________________________________________________________________
# conv4a (Conv3D)                                                (None, 4, 4, 4, 512)                                    3539456
# ____________________________________________________________________________________________________________________________________________
# conv4b (Conv3D)                                                (None, 4, 4, 4, 512)                                    7078400
# ____________________________________________________________________________________________________________________________________________
# pool4 (MaxPooling3D)                                           (None, 2, 2, 2, 512)                                    0
# ____________________________________________________________________________________________________________________________________________
# last_64 (Conv3D)                                               (None, 1, 1, 1, 64)                                     262208
# ____________________________________________________________________________________________________________________________________________
# out_class_last (Conv3D)                                        (None, 1, 1, 1, 1)                                      65
# ____________________________________________________________________________________________________________________________________________
# out_class (Flatten)                                            (None, 1)                                               0
# ============================================================================================================================================
# Total params: 13,757,953
# Trainable params: 13,757,953
# Non-trainable params: 0
# ____________________________________________________________________________________________________________________________________________
# patient_id:  ffe02fe7d2223743f7fb455dfaff3842
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (128, 128, 80)
# 到目前位置检测到的结节数量：  0
# 0.0009025669895251618
# Done in :  16.4857  seconds
# patient_id:  ff8599dd7c1139be3bad5a0351ab749a
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  0
# 0.0005443401137823904
# Done in :  23.923137  seconds
# patient_id:  ff5d8e90500cf324e7b04a2f07cf0399
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 128, 56)
# 到目前位置检测到的结节数量：  0
# 0.0018321975317868594
# Done in :  30.690211  seconds
# patient_id:  fe5c37e82b412833b8ad0abb57978377
# Predict volume shape:  (9, 10, 10)
# 到目前位置检测到的结节数量：  0
# 0.0013860709813908853
# Done in :  35.534023  seconds
# patient_id:  fe45462987bacc32dbc7126119999392
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  0
# 0.0023232891506214117
# Done in :  42.757204  seconds
# patient_id:  fe26fd2bb25112b3c2ca93eb8e34f8ed
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  0
# 0.0008980315822565362
# Done in :  48.466495  seconds
# patient_id:  fdf73dcce35167f3ed952a58f5a6f738
# Predict volume shape:  (10, 12, 12)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  0
# 0.0008127572640589428
# Done in :  54.542957  seconds
# patient_id:  fdf2a2f5b86aea0da54732056fc7ab48
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  6
# 0.0053338600156223265
# Done in :  61.834262  seconds
# patient_id:  fdcd385b0d2d12341661e1abe845be0b
# Predict volume shape:  (13, 12, 12)
# 到目前位置检测到的结节数量：  6
# 0.0007104285301558342
# Done in :  69.599686  seconds
# patient_id:  fda187bfb1d6a2ecd4abd862c7f7f94c
# Predict volume shape:  (11, 9, 9)
# 到目前位置检测到的结节数量：  10
# 0.005616547483969202
# Done in :  74.625027  seconds
# patient_id:  fd7c0fb3c0e764357aa58e5f047be614
# Predict volume shape:  (10, 11, 11)
# 到目前位置检测到的结节数量：  10
# 0.0004393568665966002
# Done in :  79.452478  seconds
# patient_id:  fd64b23b8cd8c371c8f76fbb503e4e0e
# Predict volume shape:  (10, 9, 9)
# Nodule not in mask:  (80, 104, 32)
# 到目前位置检测到的结节数量：  10
# 0.0014852410755766912
# Done in :  83.911653  seconds
# patient_id:  fd4c2d4738bc25a5c331dbc101f3323a
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (104, 176, 80)
# Nodule not in mask:  (80, 200, 80)
# 到目前位置检测到的结节数量：  10
# 0.0012845184971875937
# Done in :  89.894794  seconds
# patient_id:  fd2dd970bd3d91e5b26d7e57c03f70af
# Predict volume shape:  (11, 14, 14)
# Nodule not in mask:  (104, 224, 104)
# 到目前位置检测到的结节数量：  24
# 0.007198554033301706
# Done in :  97.27944  seconds
# patient_id:  fd0c2dfe0b0c58330675c3191cef0d5b
# Predict volume shape:  (11, 10, 10)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  32
# 0.008337356826291074
# Done in :  103.043133  seconds
# patient_id:  fcfab3eddbdf0421c39f71d651cc5c56
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (56, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (104, 176, 56)
# Nodule not in mask:  (80, 128, 80)
# Nodule not in mask:  (104, 128, 80)
# Nodule not in mask:  (80, 152, 80)
# 到目前位置检测到的结节数量：  40
# 0.006747802947322235
# Done in :  111.107583  seconds
# patient_id:  fcdc2d423356d53759a8f602d40785a6
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (56, 128, 56)
# Nodule not in mask:  (56, 152, 56)
# Nodule not in mask:  (80, 104, 80)
# 到目前位置检测到的结节数量：  40
# 0.003097566502857274
# Done in :  116.89123  seconds
# patient_id:  fc658f9bc12a751a17f16589f9e3619b
# Predict volume shape:  (10, 13, 13)
# Nodule not in mask:  (104, 128, 56)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  40
# 0.002350429589190913
# Done in :  123.594835  seconds
# patient_id:  fc545aa2f58509dc6d81ef02130b6906
# Predict volume shape:  (12, 12, 12)
# 到目前位置检测到的结节数量：  41
# 0.00120722366042407
# Done in :  130.094405  seconds
# patient_id:  fbe0c3d6e4a50ca1c1bd3101515d0ab4
# Predict volume shape:  (9, 12, 12)
# 到目前位置检测到的结节数量：  48
# 0.005895788285578775
# Done in :  135.380633  seconds
# patient_id:  fbae4d04285789dfa32124c86586dd09
# Predict volume shape:  (13, 13, 13)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (80, 200, 56)
# 到目前位置检测到的结节数量：  48
# 0.0019979575004307353
# Done in :  143.73224  seconds
# patient_id:  fbaa8548e6c3753836579c7987d0034d
# Predict volume shape:  (10, 12, 12)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (56, 200, 56)
# Nodule not in mask:  (80, 200, 56)
# Nodule not in mask:  (104, 200, 56)
# Nodule not in mask:  (56, 224, 56)
# Nodule not in mask:  (80, 224, 56)
# Nodule not in mask:  (104, 224, 56)
# 到目前位置检测到的结节数量：  48
# 0.004100546769954062
# Done in :  149.952666  seconds
# patient_id:  fb99a80cbb2f441bb90135bab5b029fe
# Predict volume shape:  (9, 12, 12)
# 到目前位置检测到的结节数量：  50
# 0.0018738636112102494
# Done in :  155.297144  seconds
# patient_id:  fb7dfb6aae597d97c2da24179df0fe56
# Predict volume shape:  (11, 13, 13)
# 到目前位置检测到的结节数量：  51
# 0.0013594782087008414
# Done in :  162.699907  seconds
# patient_id:  fb7ae70f05b6441ac4ea7187ce7c45f7
# Predict volume shape:  (10, 14, 14)
# Nodule not in mask:  (80, 200, 32)
# 到目前位置检测到的结节数量：  53
# 0.0019257254415791705
# Done in :  169.499706  seconds
# patient_id:  fb5874408966d7c6bebd3d84a5599e20
# Predict volume shape:  (11, 11, 11)
# 到目前位置检测到的结节数量：  53
# 0.00010730151384924848
# Done in :  175.156729  seconds
# patient_id:  fb57fc6377fd37bb5d42756c2736586c
# Predict volume shape:  (12, 13, 13)
# 到目前位置检测到的结节数量：  60
# 0.0034179299008564984
# Done in :  183.339877  seconds
# patient_id:  fb55849cee6473974612c17f094a38cd
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (56, 176, 32)
# Nodule not in mask:  (56, 200, 32)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  97
# 0.022599090084521937
# Done in :  190.308768  seconds
# patient_id:  fb52dd8152e53a4ca7da5403d6d0db13
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (56, 200, 56)
# Nodule not in mask:  (80, 200, 56)
# 到目前位置检测到的结节数量：  97
# 0.0013124188105289832
# Done in :  196.831957  seconds
# patient_id:  fad57a1078ddbc685e517bd8f24aa8ac
# Predict volume shape:  (11, 9, 9)
# Nodule not in mask:  (80, 104, 32)
# Nodule not in mask:  (80, 128, 32)
# 到目前位置检测到的结节数量：  97
# 0.0023595264857754496
# Done in :  201.713842  seconds
# patient_id:  fac65dbf7b6972049cfd37b5b122ec0b
# Predict volume shape:  (11, 10, 10)
# 到目前位置检测到的结节数量：  97
# 0.0010842983602580719
# Done in :  208.002912  seconds
# patient_id:  fa968673987cfd078d91641294c3bf63
# Predict volume shape:  (10, 10, 10)
# Nodule not in mask:  (80, 104, 32)
# Nodule not in mask:  (80, 104, 56)
# Nodule not in mask:  (56, 152, 56)
# 到目前位置检测到的结节数量：  97
# 0.0029470977911610578
# Done in :  212.911336  seconds
# patient_id:  fa9575f64e6881c6b2730f0e225c9573
# Predict volume shape:  (11, 11, 11)
# 到目前位置检测到的结节数量：  98
# 0.0014673208808386215
# Done in :  218.311802  seconds
# patient_id:  fa7bf17071e3234ab1f350341303b174
# Predict volume shape:  (13, 13, 13)
# 到目前位置检测到的结节数量：  98
# 0.00048515762180729424
# Done in :  226.477949  seconds
# patient_id:  fa744c0374ccc6aaf6711f463a9e5bc2
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  98
# 0.0011033021586902992
# Done in :  234.904425  seconds
# patient_id:  fa45178d023325b255a3d4fc3e96cb7d
# Predict volume shape:  (10, 11, 11)
# 到目前位置检测到的结节数量：  98
# 0.0005845246766659643
# Done in :  240.970081  seconds
# patient_id:  f9ce0c5ded59a58b9d7ca5200e6b1182
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 128, 56)
# 到目前位置检测到的结节数量：  98
# 0.0007851236731341982
# Done in :  246.760942  seconds
# patient_id:  f938f9022abf7f1072fe9df79db7eccd
# Predict volume shape:  (10, 12, 12)
# 到目前位置检测到的结节数量：  106
# 0.005578866935534867
# Done in :  252.457034  seconds
# patient_id:  f8f66fca04d2e67eacd86ea154827a4c
# Predict volume shape:  (11, 14, 14)
# Nodule not in mask:  (80, 176, 104)
# 到目前位置检测到的结节数量：  114
# 0.005082786781863535
# Done in :  260.087362  seconds
# patient_id:  f8ecf6be8ae631c6dd694c9638a02b45
# Predict volume shape:  (12, 11, 11)
# 到目前位置检测到的结节数量：  140
# 0.018738206346188113
# Done in :  266.303468  seconds
# patient_id:  f89e3d0867e27be8e19d7ed50e1eb7e8
# Predict volume shape:  (11, 13, 13)
# Nodule not in mask:  (104, 128, 32)
# 到目前位置检测到的结节数量：  140
# 0.0009798104892951996
# Done in :  273.083442  seconds
# patient_id:  f89a08a93f1ceaccb0cba52156fd6f03
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 128, 56)
# Nodule not in mask:  (56, 152, 56)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  140
# 0.0022278751462225473
# Done in :  278.669738  seconds
# patient_id:  f88ed45f3436cb30e494409dae76df5d
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (80, 128, 56)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (104, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  150
# 0.008134666720633616
# Done in :  285.843228  seconds
# patient_id:  f83c62177ee552891d22df33be12ab07
# Predict volume shape:  (11, 13, 13)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  150
# 0.0013694133467440995
# Done in :  293.044071  seconds
# patient_id:  f82560aeea0309873716efe3aa71ef0a
# Predict volume shape:  (11, 13, 13)
# 到目前位置检测到的结节数量：  150
# 0.00026351127629533407
# Done in :  299.290252  seconds
# patient_id:  f7cdd95c94818875ece1175561025038
# Predict volume shape:  (13, 13, 13)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (104, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (104, 176, 56)
# Nodule not in mask:  (80, 199, 56)
# 到目前位置检测到的结节数量：  150
# 0.0025074051197231974
# Done in :  307.989281  seconds
# patient_id:  f7c387290d7e3074501eac167c849000
# Predict volume shape:  (12, 10, 10)
# 到目前位置检测到的结节数量：  158
# 0.008196231730264781
# Done in :  314.225016  seconds
# patient_id:  f7a03adba817f2a2249b9dee0586f4be
# Predict volume shape:  (12, 11, 11)
# 到目前位置检测到的结节数量：  158
# 0.0008727260237510453
# Done in :  321.10566  seconds
# patient_id:  f79681d8561b6443a5b95f78f3ea6411
# Predict volume shape:  (12, 13, 13)
# 到目前位置检测到的结节数量：  158
# 0.0005329750692728853
# Done in :  328.767949  seconds
# patient_id:  f78944bd1732001a3c62723a8cc19856
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  162
# 0.0038862966696913193
# Done in :  335.055546  seconds
# patient_id:  f77fd9fd7966b346ce8e7efcb96c7c53
# Predict volume shape:  (12, 13, 13)
# 到目前位置检测到的结节数量：  162
# 0.00019764955174146615
# Done in :  342.178025  seconds
# patient_id:  f76143416ee2c8e1251f45f108fed468
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  170
# 0.006991657841469512
# Done in :  347.810574  seconds
# patient_id:  f74cbe4dda0f80dd66e15e64563689c6
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (104, 200, 56)
# 到目前位置检测到的结节数量：  170
# 0.0021183143810731865
# Done in :  354.849784  seconds
# patient_id:  f73624b8b22774acf9a3e2c748131eac
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  172
# 0.0017173203373818554
# Done in :  361.591353  seconds
# patient_id:  f725f46908f16062fd12c141eb47c6a7
# Predict volume shape:  (9, 12, 12)
# 到目前位置检测到的结节数量：  177
# 0.0037430102660152846
# Done in :  366.611978  seconds
# patient_id:  f6c9e875d7adfe7add08f43528810f72
# Predict volume shape:  (10, 10, 10)
# Nodule not in mask:  (56, 152, 56)
# 到目前位置检测到的结节数量：  193
# 0.017669340722282666
# Done in :  372.012799  seconds
# patient_id:  f6bf2c352e3c5b13ae48f077570f3d15
# Predict volume shape:  (12, 12, 12)
# 到目前位置检测到的结节数量：  193
# 0.00012695535126606305
# Done in :  378.722576  seconds
# patient_id:  f6a9611b3afd5c6a5fb4a718cd2c38c2
# Predict volume shape:  (11, 11, 11)
# 到目前位置检测到的结节数量：  193
# 0.0005205888291886341
# Done in :  384.166035  seconds
# patient_id:  f6a2e171a3be579b564cd855985ab9d1
# Predict volume shape:  (10, 11, 11)
# 到目前位置检测到的结节数量：  193
# 0.0013055853695498405
# Done in :  389.684122  seconds
# patient_id:  f69c80f898c9dfd8d3595b7ca7b8c66c
# Predict volume shape:  (11, 9, 9)
# 到目前位置检测到的结节数量：  193
# 0.0004369515127363818
# Done in :  394.921193  seconds
# patient_id:  f63f2f63e2619012b4c798fd638c8b8a
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (104, 128, 56)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  197
# 0.004143047713859828
# Done in :  402.264424  seconds
# patient_id:  f5ff7734997820b45dafa75dff60ece8
# Predict volume shape:  (10, 10, 10)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  197
# 0.001993856235529357
# Done in :  407.479048  seconds
# patient_id:  f599c9bb0bd19126e13fba8b63d2de41
# Predict volume shape:  (11, 14, 14)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (80, 200, 56)
# 到目前位置检测到的结节数量：  197
# 0.0018359541193991508
# Done in :  414.601957  seconds
# patient_id:  f5717f7cbc08d8bd942cd4c1128e3339
# Predict volume shape:  (9, 12, 12)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (56, 176, 32)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  206
# 0.009759247383286165
# Done in :  420.29319  seconds
# patient_id:  f5713e8c98ef5378ea678fb8d9192e13
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (56, 128, 32)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (80, 104, 56)
# Nodule not in mask:  (200, 104, 104)
# 到目前位置检测到的结节数量：  206
# 0.0034189196673965797
# Done in :  427.188296  seconds
# patient_id:  f5630f467acd9aa977b61a3e5780c2eb
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  206
# 0.0006380925854308556
# Done in :  432.671739  seconds
# patient_id:  f55f99177e8b4b267c71b4e5fa4116be
# Predict volume shape:  (11, 11, 11)
# 到目前位置检测到的结节数量：  206
# 0.0001395752188061957
# Done in :  438.576265  seconds
# patient_id:  f55b8ee990408001671d76c3595afacf
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (80, 104, 80)
# Nodule not in mask:  (104, 104, 80)
# 到目前位置检测到的结节数量：  206
# 0.0022479510395219658
# Done in :  444.229326  seconds
# patient_id:  f52bd66210db45189027991781e1162b
# Predict volume shape:  (10, 12, 12)
# Nodule not in mask:  (104, 176, 56)
# Nodule not in mask:  (104, 200, 56)
# 到目前位置检测到的结节数量：  206
# 0.0021428246506055653
# Done in :  450.106999  seconds
# patient_id:  f4d23e0272a2ce5bfc7f07033d4f2e7d
# Predict volume shape:  (12, 13, 13)
# 到目前位置检测到的结节数量：  215
# 0.0043969320102312725
# Done in :  457.635188  seconds
# patient_id:  f4bee414210374e68b6746f70b38d461
# Predict volume shape:  (10, 13, 13)
# Nodule not in mask:  (56, 176, 56)
# Nodule not in mask:  (80, 200, 56)
# Nodule not in mask:  (80, 176, 80)
# 到目前位置检测到的结节数量：  215
# 0.0018858280258483959
# Done in :  464.390359  seconds
# patient_id:  f467795ce3b50a771085d79ae8d29ecc
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 200, 56)
# 到目前位置检测到的结节数量：  215
# 0.0008648557478228845
# Done in :  472.135771  seconds
# patient_id:  f44dd045f6dcb1e477e6d3dc0f29d7e8
# Predict volume shape:  (12, 14, 14)
# 到目前位置检测到的结节数量：  215
# 0.00034791448935555147
# Done in :  480.403131  seconds
# patient_id:  f447ac9884a349a4ae56326cf680ae18
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (56, 152, 80)
# 到目前位置检测到的结节数量：  215
# 0.0007218085232102808
# Done in :  487.361563  seconds
# patient_id:  f43843b39a5be8cd30dab59bd11499ed
# Predict volume shape:  (10, 10, 10)
# 到目前位置检测到的结节数量：  215
# 0.0009779158661403164
# Done in :  492.001924  seconds
# patient_id:  f42a0343e5b5154c6a184fc955d8f20f
# Predict volume shape:  (13, 14, 14)
# 到目前位置检测到的结节数量：  225
# 0.004367076228856837
# Done in :  500.562764  seconds
# patient_id:  f3f6f40ccb01276d722d52701cab1754
# Predict volume shape:  (14, 15, 15)
# Nodule not in mask:  (176, 272, 321)
# Nodule not in mask:  (176, 296, 321)
# Nodule not in mask:  (200, 296, 321)
# 到目前位置检测到的结节数量：  229
# 0.0022085178503482884
# Done in :  511.214146  seconds
# patient_id:  f3eafe72b1e9528116f3c430ab73a2ae
# Predict volume shape:  (13, 12, 12)
# Nodule not in mask:  (80, 200, 32)
# 到目前位置检测到的结节数量：  236
# 0.005011156900053688
# Done in :  518.899709  seconds
# patient_id:  f3d40bbf94a7951dee3b0028e301a126
# Predict volume shape:  (11, 9, 9)
# 到目前位置检测到的结节数量：  237
# 0.002677720189359722
# Done in :  523.93308  seconds
# patient_id:  f39dacd5f134f3f4482094d3f8a0aff1
# Predict volume shape:  (10, 14, 14)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (80, 200, 56)
# 到目前位置检测到的结节数量：  238
# 0.0022025435842722564
# Done in :  531.535174  seconds
# patient_id:  f39a1e54d79731e4417aa8159d19b7d4
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (56, 176, 56)
# 到目前位置检测到的结节数量：  238
# 0.0013402706255067137
# Done in :  538.982289  seconds
# patient_id:  f395ca14ccb03ad40e98d1473cf686ef
# Predict volume shape:  (11, 11, 11)
# 到目前位置检测到的结节数量：  238
# 0.0007976548215554198
# Done in :  544.368109  seconds
# patient_id:  f37d1d5c299d4838b294cf82902675b0
# Predict volume shape:  (10, 9, 9)
# 到目前位置检测到的结节数量：  238
# 3.714258727117506e-06
# Done in :  549.097066  seconds
# patient_id:  f2f23b265b2a3b977cb81fe3193d7c2c
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (80, 176, 32)
# Nodule not in mask:  (80, 200, 32)
# Nodule not in mask:  (80, 224, 32)
# 到目前位置检测到的结节数量：  238
# 0.0021799657103170633
# Done in :  556.367056  seconds
# patient_id:  f2e952758095bc50691ab02f724568d2
# Predict volume shape:  (10, 14, 14)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  238
# 0.000765522581492984
# Done in :  563.533474  seconds
# patient_id:  f2ca85bb9ae82a3d79b9f321f727ac19
# Predict volume shape:  (13, 13, 13)
# Nodule not in mask:  (80, 152, 80)
# Nodule not in mask:  (80, 176, 80)
# 到目前位置检测到的结节数量：  242
# 0.002603978903530564
# Done in :  571.821265  seconds
# patient_id:  f29d00ddf6d9846aa600c3f0edf5f952
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (272, 152, 32)
# Nodule not in mask:  (272, 176, 32)
# Nodule not in mask:  (248, 176, 56)
# 到目前位置检测到的结节数量：  246
# 0.003788576724128462
# Done in :  579.708436  seconds
# patient_id:  f27d7bf8df3cf0cd187682fc6860b755
# Predict volume shape:  (11, 14, 14)
# 到目前位置检测到的结节数量：  246
# 0.0004056476108723867
# Done in :  586.533543  seconds
# patient_id:  f25c425c827b35fcbaa23f2ed671540b
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  246
# 0.0002679311436188867
# Done in :  592.892385  seconds
# patient_id:  f243bd277f1876a77a0fb18f9092105a
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (152, 80, 32)
# Nodule not in mask:  (56, 128, 32)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (56, 176, 32)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  246
# 0.0028338316885194647
# Done in :  599.744905  seconds
# patient_id:  f228862e9f9c6ad7993ded4e088c5050
# Predict volume shape:  (12, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  246
# 0.0006961684439087103
# Done in :  606.221502  seconds
# patient_id:  f207bb8bcccdc76143380849402a4f21
# Predict volume shape:  (12, 13, 13)
# 到目前位置检测到的结节数量：  246
# 0.0005574580042630623
# Done in :  614.045616  seconds
# patient_id:  f1a64fda219db48bcfb8ad3823ef9fc1
# Predict volume shape:  (11, 9, 9)
# 到目前位置检测到的结节数量：  246
# 7.258023787662245e-05
# Done in :  619.307627  seconds
# patient_id:  f17867cc3e579dc2fc6f0334bc43a91d
# Predict volume shape:  (14, 12, 12)
# Nodule not in mask:  (56, 80, 56)
# Nodule not in mask:  (56, 104, 56)
# Nodule not in mask:  (80, 104, 56)
# 到目前位置检测到的结节数量：  248
# 0.002256827397045166
# Done in :  627.890301  seconds
# patient_id:  f136a3df63637b499704a49fc0e3dfaf
# Predict volume shape:  (12, 11, 11)
# Nodule not in mask:  (56, 176, 80)
# Nodule not in mask:  (80, 176, 80)
# 到目前位置检测到的结节数量：  248
# 0.0013066972260366632
# Done in :  633.998187  seconds
# patient_id:  f0f72264cd822301852578cc71288d3c
# Predict volume shape:  (13, 11, 11)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (80, 176, 32)
# Nodule not in mask:  (104, 176, 32)
# 到目前位置检测到的结节数量：  248
# 0.0017273238325321162
# Done in :  640.904817  seconds
# patient_id:  f0459473753b99105e9723f122022ad0
# Predict volume shape:  (10, 9, 9)
# 到目前位置检测到的结节数量：  248
# 0.0007263852174978534
# Done in :  645.759302  seconds
# patient_id:  f0310ffc724faf9f7aef2c418127ee68
# Predict volume shape:  (13, 13, 13)
# Nodule not in mask:  (80, 199, 104)
# Nodule not in mask:  (104, 199, 104)
# 到目前位置检测到的结节数量：  248
# 0.0009733310170260032
# Done in :  653.698905  seconds
# patient_id:  f029c73f6f8753e7447c4e9f22e917ad
# Predict volume shape:  (9, 10, 10)
# 到目前位置检测到的结节数量：  256
# 0.010299720036483046
# Done in :  658.867323  seconds
# patient_id:  eff5b5a7c7245fa8f4661d7e88f8bc7f
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (56, 176, 56)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (56, 152, 80)
# 到目前位置检测到的结节数量：  256
# 0.0022968451003430646
# Done in :  664.322051  seconds
# patient_id:  efd5b9e8cb651e18eba6a9623e36e7be
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (128, 200, 32)
# 到目前位置检测到的结节数量：  256
# 0.0003232321161154948
# Done in :  671.282465  seconds
# patient_id:  efcb6def7a2080243052b6046186ab24
# Predict volume shape:  (13, 12, 12)
# Nodule not in mask:  (80, 128, 56)
# 到目前位置检测到的结节数量：  257
# 0.0010319736030429286
# Done in :  678.583373  seconds
# patient_id:  ef8a19fb5314b3222482fa325dd49467
# Predict volume shape:  (9, 9, 9)
# 到目前位置检测到的结节数量：  265
# 0.010659464552599595
# Done in :  682.656509  seconds
# patient_id:  ef6a37afe024d33b4b1bb2fdee054a59
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (56, 128, 32)
# Nodule not in mask:  (80, 128, 32)
# 到目前位置检测到的结节数量：  268
# 0.0038586133934507103
# Done in :  688.134011  seconds
# patient_id:  ef3be197823bfa8c6976ca2621e253d5
# Predict volume shape:  (10, 12, 12)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (56, 176, 32)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  268
# 0.0021108751051912913
# Done in :  694.447626  seconds
# patient_id:  eefc3f380cc72d6fa830972151df01ad
# Predict volume shape:  (11, 9, 9)
# Nodule not in mask:  (56, 104, 56)
# Nodule not in mask:  (80, 104, 56)
# Nodule not in mask:  (56, 128, 56)
# 到目前位置检测到的结节数量：  268
# 0.002784702742526872
# Done in :  699.604682  seconds
# patient_id:  eef0e41b1a96cf8c55723fa6aa2f3dc6
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  268
# 0.0005276954758255394
# Done in :  706.076066  seconds
# patient_id:  eee8e1b2533abcb73e4b03969a3a5904
# Predict volume shape:  (10, 13, 13)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (104, 176, 56)
# 到目前位置检测到的结节数量：  268
# 0.001755179975452613
# Done in :  712.102488  seconds
# patient_id:  eed63953a76074dd5ef7360e131f4852
# Predict volume shape:  (10, 11, 11)
# 到目前位置检测到的结节数量：  272
# 0.00371123570198822
# Done in :  717.473619  seconds
# patient_id:  eed4db0cb0576c274de569e98a56a270
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  272
# 0.0002866759637133601
# Done in :  723.892744  seconds
# patient_id:  eebd87b91489548bdfc1c76a20999a54
# Predict volume shape:  (13, 11, 11)
# Nodule not in mask:  (80, 128, 80)
# 到目前位置检测到的结节数量：  272
# 0.0011274712222160306
# Done in :  731.85112  seconds
# patient_id:  eeb1659b92b00e20bd8b6e7eef6b5c9d
# Predict volume shape:  (12, 10, 10)
# Nodule not in mask:  (80, 104, 32)
# 到目前位置检测到的结节数量：  272
# 0.0005551250843283839
# Done in :  737.63656  seconds
# patient_id:  ee9c580272cd02741df7299892602ac7
# Predict volume shape:  (10, 12, 12)
# 到目前位置检测到的结节数量：  272
# 0.0009479944840367061
# Done in :  743.568711  seconds
# patient_id:  ee984e8fba88691aac4992fbb14f6e97
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  272
# 0.0012045888797608114
# Done in :  750.208587  seconds
# patient_id:  ee88217bee233a3bfc971b450e3d8b85
# Predict volume shape:  (9, 13, 13)
# Nodule not in mask:  (104, 128, 32)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (80, 176, 32)
# Nodule not in mask:  (104, 176, 32)
# 到目前位置检测到的结节数量：  272
# 0.0024545986125629905
# Done in :  756.40562  seconds
# patient_id:  ee71210fa398cbb080f6c537a503e806
# Predict volume shape:  (10, 9, 9)
# 到目前位置检测到的结节数量：  272
# 0.0006974937654362296
# Done in :  761.455759  seconds
# patient_id:  edbf53a8478049de1494b213fdf942e6
# Predict volume shape:  (10, 13, 13)
# Nodule not in mask:  (104, 128, 32)
# 到目前位置检测到的结节数量：  272
# 0.0006835180583210028
# Done in :  768.54258  seconds
# patient_id:  edae2e1edd1217d0c9e20eff2a7b2dd8
# Predict volume shape:  (9, 10, 10)
# 到目前位置检测到的结节数量：  272
# 7.419315615457445e-05
# Done in :  773.74569  seconds
# patient_id:  edad1a7e85b5443e0ae9e654d2adbcba
# Predict volume shape:  (11, 10, 10)
# Nodule not in mask:  (80, 128, 80)
# Nodule not in mask:  (56, 104, 104)
# 到目前位置检测到的结节数量：  272
# 0.002665367767285481
# Done in :  778.911422  seconds
# patient_id:  eda58f4918c4b506cd156702bf8a56a3
# Predict volume shape:  (13, 10, 10)
# 到目前位置检测到的结节数量：  272
# 0.00027340113004607785
# Done in :  784.943097  seconds
# patient_id:  ed83b655a1bbad40a782ad13cf27ce8f
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (80, 104, 56)
# Nodule not in mask:  (56, 128, 56)
# 到目前位置检测到的结节数量：  272
# 0.001735162598586681
# Done in :  791.54896  seconds
# patient_id:  ed49b57854f5580658fb3510676e03dd
# Predict volume shape:  (14, 9, 9)
# Nodule not in mask:  (56, 128, 104)
# 到目前位置检测到的结节数量：  272
# 0.0021008027051648967
# Done in :  796.724775  seconds
# patient_id:  ed0f3c1619b2becec76ba5df66e1ea56
# Predict volume shape:  (13, 12, 12)
# 到目前位置检测到的结节数量：  286
# 0.008045522158522703
# Done in :  804.425579  seconds
# patient_id:  ebd601d40a18634b100c92e7db39f585
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  286
# 0.0016868465079626614
# Done in :  811.979674  seconds
# patient_id:  ebcdfabecf4b46b1e55e4a4c75a0afb0
# Predict volume shape:  (12, 14, 14)
# 到目前位置检测到的结节数量：  294
# 0.0036324825392478172
# Done in :  820.10829  seconds
# patient_id:  eba4bfb93928d424ff21b5be96b5c09b
# Predict volume shape:  (13, 12, 12)
# 到目前位置检测到的结节数量：  305
# 0.006219334571315687
# Done in :  827.406437  seconds
# patient_id:  eba18d04b18084ef64be8f22bb7905ca
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (128, 104, 56)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  307
# 0.0018354766066184525
# Done in :  834.864943  seconds
# patient_id:  eb9db3f740f8e153e85f83c57bc4e522
# Predict volume shape:  (11, 14, 14)
# Nodule not in mask:  (80, 128, 56)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  307
# 0.0010029061109924848
# Done in :  842.809158  seconds
# patient_id:  eb8d5136918d6859ca3cc3abafe369ac
# Predict volume shape:  (11, 13, 13)
# 到目前位置检测到的结节数量：  315
# 0.004596532823003633
# Done in :  850.567768  seconds
# patient_id:  eb008af181f3791fdce2376cf4773733
# Predict volume shape:  (13, 12, 12)
# 到目前位置检测到的结节数量：  317
# 0.0017681758422169065
# Done in :  857.510061  seconds
# patient_id:  eaf753dc137e12fd06e96d27f3111043
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  327
# 0.0067072714110996325
# Done in :  863.923935  seconds
# patient_id:  eaeebb7a63edc8a329a7c5fbc583a507
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  335
# 0.004899964249674468
# Done in :  871.404697  seconds
# patient_id:  ead64f9269f2200e1d439960a1e069b4
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  347
# 0.010819338745540417
# Done in :  876.869806  seconds
# patient_id:  eacb38abacf1214f3b456b6c9fa78697
# Predict volume shape:  (12, 10, 10)
# Nodule not in mask:  (56, 128, 56)
# 到目前位置检测到的结节数量：  347
# 0.0017285082133763963
# Done in :  883.361623  seconds
# patient_id:  ea7373271a2441b5864df2053c0f5c3e
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  357
# 0.005418874381665771
# Done in :  891.362284  seconds
# patient_id:  ea3a771ef05e288409e0250ea893cf87
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 176, 80)
# Nodule not in mask:  (80, 200, 80)
# Nodule not in mask:  (104, 200, 80)
# 到目前位置检测到的结节数量：  357
# 0.0022012533191373045
# Done in :  899.26609  seconds
# patient_id:  ea01deecde93cd9503a049d71d46e6d5
# Predict volume shape:  (11, 13, 13)
# 到目前位置检测到的结节数量：  357
# 0.0007533076524965208
# Done in :  906.507246  seconds
# patient_id:  e9ccf1ce85c39779fafb9ec703c71555
# Predict volume shape:  (9, 10, 10)
# 到目前位置检测到的结节数量：  359
# 0.0026755941546370014
# Done in :  911.829891  seconds
# patient_id:  e9a27e2645e1fad9434ce765f678585f
# Predict volume shape:  (13, 13, 13)
# 到目前位置检测到的结节数量：  359
# 0.0006777139731633368
# Done in :  920.047925  seconds
# patient_id:  e977737394cee9abb19ad07310aae8eb
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (56, 152, 56)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  359
# 0.0014797066969351048
# Done in :  926.932777  seconds
# patient_id:  e92a2ed80510513497d5252b001cfa3e
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  359
# 0.0005468678421321542
# Done in :  933.571129  seconds
# patient_id:  e8eb842ee04bbad407f85fe671f24d4f
# Predict volume shape:  (12, 10, 10)
# 到目前位置检测到的结节数量：  360
# 0.0018753550645078916
# Done in :  939.543358  seconds
# patient_id:  e8be143b9f5e352f71043b24f79f5a17
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  360
# 1.011534398880078e-05
# Done in :  946.33898  seconds
# patient_id:  e858263b89f0bb57597bcff325eaeecf
# Predict volume shape:  (12, 15, 15)
# Nodule not in mask:  (80, 176, 80)
# Nodule not in mask:  (80, 200, 80)
# Nodule not in mask:  (80, 224, 80)
# Nodule not in mask:  (104, 224, 80)
# Nodule not in mask:  (104, 176, 104)
# Nodule not in mask:  (104, 200, 104)
# 到目前位置检测到的结节数量：  360
# 0.0024851813667153408
# Done in :  955.103566  seconds
# patient_id:  e7d76f0723911280b64f0f83a4990c97
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  360
# 0.0003037260842263581
# Done in :  961.884011  seconds
# patient_id:  e7cb27a5362a7098e1437bfb1224d2dc
# Predict volume shape:  (9, 10, 10)
# 到目前位置检测到的结节数量：  371
# 0.012128948439981552
# Done in :  966.709077  seconds
# patient_id:  e7adb2e4409683b9490e34b6b3604d9e
# Predict volume shape:  (13, 12, 12)
# 到目前位置检测到的结节数量：  374
# 0.001979984269455447
# Done in :  974.655032  seconds
# patient_id:  e79f52e833ccca893509f0fdeeb26e9f
# Predict volume shape:  (11, 10, 10)
# Nodule not in mask:  (80, 128, 56)
# 到目前位置检测到的结节数量：  374
# 0.0010284521197401228
# Done in :  979.939665  seconds
# patient_id:  e787e5fd289a9f1f6bba31569b7ad384
# Predict volume shape:  (11, 11, 11)
# 到目前位置检测到的结节数量：  374
# 0.0011012647413383286
# Done in :  985.516989  seconds
# patient_id:  e709901da9ba15a95d4a29906edc01dd
# Predict volume shape:  (9, 12, 12)
# 到目前位置检测到的结节数量：  377
# 0.0025574722652247387
# Done in :  991.116192  seconds
# patient_id:  e6f4757b8f315f31559c5c256cb8dead
# Predict volume shape:  (13, 13, 13)
# Nodule not in mask:  (80, 176, 80)
# 到目前位置检测到的结节数量：  385
# 0.00454657304319872
# Done in :  999.376297  seconds
# patient_id:  e6d8b2631843a24e6761f2723ea30788
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  385
# 0.0014427947778177408
# Done in :  1006.716442  seconds
# patient_id:  e6d8ae8c3b0817df994a1ce3b37a7efb
# Predict volume shape:  (10, 12, 12)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  385
# 0.0005942212998543261
# Done in :  1012.501617  seconds
# patient_id:  e6d4a747235bfcc1feac759571c8485c
# Predict volume shape:  (12, 11, 11)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  385
# 0.001085447511075271
# Done in :  1018.815849  seconds
# patient_id:  e6b3e750c6c7a70ca512d77defcfe615
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 152, 80)
# Nodule not in mask:  (80, 176, 80)
# Nodule not in mask:  (104, 176, 80)
# Nodule not in mask:  (80, 200, 80)
# Nodule not in mask:  (104, 200, 80)
# 到目前位置检测到的结节数量：  385
# 0.0020610838088131666
# Done in :  1026.294742  seconds
# patient_id:  e67bc6cd24a71a486b626592d591a2da
# Predict volume shape:  (11, 10, 10)
# Nodule not in mask:  (56, 128, 32)
# 到目前位置检测到的结节数量：  385
# 0.0011425032698365691
# Done in :  1032.051886  seconds
# patient_id:  e659f6517c4df17e86d4d87181396ea6
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (80, 224, 56)
# 到目前位置检测到的结节数量：  392
# 0.003916036602222184
# Done in :  1040.526403  seconds
# patient_id:  e63f43056330bc418a11208aa3a9e7f0
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (56, 176, 32)
# 到目前位置检测到的结节数量：  392
# 0.0011136344224449565
# Done in :  1047.416999  seconds
# patient_id:  e6214ef879c6d01ae598161e50e23c0c
# Predict volume shape:  (10, 10, 10)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  392
# 0.0018385936641326644
# Done in :  1051.851681  seconds
# patient_id:  e6160ed0ff2eb214abd4df9a3c336c1d
# Predict volume shape:  (8, 12, 12)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  397
# 0.005928035232030481
# Done in :  1056.799462  seconds
# patient_id:  e60d99ea9648e1ce859eb0b386365e26
# Predict volume shape:  (10, 13, 13)
# Nodule not in mask:  (80, 128, 80)
# 到目前位置检测到的结节数量：  397
# 0.0015368108609328263
# Done in :  1063.193994  seconds
# patient_id:  e608c0e6cf3adf3c9939593a3c322ef7
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  397
# 0.00033100576520446494
# Done in :  1069.297215  seconds
# patient_id:  e5cf847e616cc2fe94816ffa547d2614
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  402
# 0.004068532596958426
# Done in :  1076.08461  seconds
# patient_id:  e5c68cfa0f33540da3098800f0daae2c
# Predict volume shape:  (11, 9, 9)
# 到目前位置检测到的结节数量：  402
# 0.0005404780966346571
# Done in :  1080.93598  seconds
# patient_id:  e58cc57cab8a1738041b72b156fedc56
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  421
# 0.013875753752825376
# Done in :  1087.744595  seconds
# patient_id:  e58b78dc31d80a50285816f4ecd661e3
# Predict volume shape:  (11, 11, 11)
# 到目前位置检测到的结节数量：  435
# 0.011510506713344384
# Done in :  1093.452356  seconds
# patient_id:  e572e978c2b50aca781e6302937e5b13
# Predict volume shape:  (11, 13, 13)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  435
# 0.0006303574752786142
# Done in :  1100.468537  seconds
# patient_id:  e56b9f25a47a42f4ae4085005c46109c
# Predict volume shape:  (11, 13, 13)
# 到目前位置检测到的结节数量：  435
# 0.00019779389715522103
# Done in :  1107.489491  seconds
# patient_id:  e54b574a7e7c650edc224cbdede9e675
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 200, 56)
# Nodule not in mask:  (104, 200, 56)
# 到目前位置检测到的结节数量：  435
# 0.0014581843632240918
# Done in :  1115.332329  seconds
# patient_id:  e5438d842118e579a340a78f3c5775cc
# Predict volume shape:  (11, 14, 14)
# Nodule not in mask:  (80, 176, 56)
# Nodule not in mask:  (80, 200, 56)
# 到目前位置检测到的结节数量：  435
# 0.0008298548743782042
# Done in :  1123.104657  seconds
# patient_id:  e537c91cdfa97d20a39df7ef04a52570
# Predict volume shape:  (12, 13, 13)
# 到目前位置检测到的结节数量：  443
# 0.004439767339343234
# Done in :  1130.880873  seconds
# patient_id:  e4ff18b33b7110a64f497e177102f23d
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 128, 56)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  443
# 0.0013027311697105107
# Done in :  1137.527132  seconds
# patient_id:  e4a87107f94e4a8e32b735d18cef1137
# Predict volume shape:  (11, 10, 10)
# Nodule not in mask:  (56, 152, 56)
# Nodule not in mask:  (56, 128, 80)
# 到目前位置检测到的结节数量：  443
# 0.0018056333391813244
# Done in :  1144.14071  seconds
# patient_id:  e46973b13a7a6f421430d81fc1dda970
# Predict volume shape:  (11, 14, 14)
# 到目前位置检测到的结节数量：  443
# 0.00083007509257249
# Done in :  1151.98002  seconds
# patient_id:  e4436b5914162ff7efea2bdfb71c19ae
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  443
# 0.0016463530204633673
# Done in :  1159.257252  seconds
# patient_id:  e4421d2d5318845c1cccbc6fa308a96e
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (80, 176, 32)
# Nodule not in mask:  (80, 104, 56)
# 到目前位置检测到的结节数量：  447
# 0.00570140449912255
# Done in :  1165.481158  seconds
# patient_id:  e43afa905c8e279f818b2d5104f6762b
# Predict volume shape:  (13, 12, 12)
# 到目前位置检测到的结节数量：  447
# 0.0007012709222549547
# Done in :  1173.326907  seconds
# patient_id:  e42815372aa308f5943847ad06f529de
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 224, 32)
# Nodule not in mask:  (104, 152, 56)
# Nodule not in mask:  (104, 176, 56)
# Nodule not in mask:  (80, 200, 56)
# Nodule not in mask:  (104, 200, 56)
# Nodule not in mask:  (224, 152, 128)
# 到目前位置检测到的结节数量：  447
# 0.003620612111579508
# Done in :  1181.525684  seconds
# patient_id:  e42065c1145ccf734312cb9edbe5234b
# Predict volume shape:  (10, 15, 15)
# Nodule not in mask:  (104, 247, 80)
# Nodule not in mask:  (104, 200, 104)
# Nodule not in mask:  (128, 200, 104)
# 到目前位置检测到的结节数量：  447
# 0.0015203805969556566
# Done in :  1189.1131  seconds
# patient_id:  e414153d0e52f70cbe27c129911445a0
# Predict volume shape:  (9, 12, 12)
# Nodule not in mask:  (104, 200, 32)
# Nodule not in mask:  (80, 224, 32)
# Nodule not in mask:  (104, 224, 32)
# 到目前位置检测到的结节数量：  447
# 0.0016045953363307123
# Done in :  1194.021308  seconds
# patient_id:  e3e518324e1a85b85f15d9127ed9ea89
# Predict volume shape:  (12, 10, 10)
# 到目前位置检测到的结节数量：  447
# 0.0009089931414101567
# Done in :  1199.397659  seconds
# patient_id:  e3bc0a970a4af5d52826e06742f90e5b
# Predict volume shape:  (11, 10, 10)
# Nodule not in mask:  (56, 104, 32)
# Nodule not in mask:  (56, 128, 32)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  447
# 0.0024186961709550554
# Done in :  1205.406315  seconds
# patient_id:  e3a9a6f8d21c6c459728066bcf18c615
# Predict volume shape:  (11, 10, 10)
# Nodule not in mask:  (56, 128, 32)
# Nodule not in mask:  (56, 153, 32)
# 到目前位置检测到的结节数量：  447
# 0.001511380132990188
# Done in :  1211.379638  seconds
# patient_id:  e38789c5eabb3005bfb82a5298055ba0
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (56, 128, 32)
# 到目前位置检测到的结节数量：  449
# 0.0025717114526662157
# Done in :  1216.968056  seconds
# patient_id:  e3423505ef6b43f03c5d7bde52a5a78c
# Predict volume shape:  (9, 12, 12)
# 到目前位置检测到的结节数量：  461
# 0.009530045778081853
# Done in :  1223.102  seconds
# patient_id:  e33c25d0dbca5e54385f2100ce523467
# Predict volume shape:  (12, 11, 11)
# Nodule not in mask:  (80, 128, 56)
# 到目前位置检测到的结节数量：  461
# 0.0008500460111240874
# Done in :  1229.600625  seconds
# patient_id:  e314fd13809db0132443b924401d828b
# Predict volume shape:  (11, 10, 10)
# 到目前位置检测到的结节数量：  461
# 0.0005690923203693726
# Done in :  1235.279331  seconds
# patient_id:  e3034ac9c2799b9a9cee2111593d9853
# Predict volume shape:  (11, 14, 14)
# Nodule not in mask:  (104, 176, 56)
# Nodule not in mask:  (128, 224, 56)
# Nodule not in mask:  (104, 200, 80)
# 到目前位置检测到的结节数量：  461
# 0.0021484367556695804
# Done in :  1242.833506  seconds
# patient_id:  e2ea2f046495909ff89e18e05f710fee
# Predict volume shape:  (9, 11, 11)
# 到目前位置检测到的结节数量：  461
# 0.0011668649119844464
# Done in :  1247.539495  seconds
# patient_id:  e2bcbfe1ab0f9ddc5d6234f819cd5df5
# Predict volume shape:  (8, 13, 13)
# 到目前位置检测到的结节数量：  461
# 2.9636410339227714e-05
# Done in :  1252.637402  seconds
# patient_id:  e2b7fe7fbb002029640c0e65e3051888
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (80, 104, 80)
# Nodule not in mask:  (80, 128, 80)
# 到目前位置检测到的结节数量：  465
# 0.0034080940783979036
# Done in :  1260.02217  seconds
# patient_id:  e2a7eaebd0830061e77690aa48f11936
# Predict volume shape:  (10, 10, 10)
# Nodule not in mask:  (80, 104, 32)
# Nodule not in mask:  (80, 128, 32)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  465
# 0.0025104515379097128
# Done in :  1265.801911  seconds
# patient_id:  e1f3a01e73d706b7e9c30c0a17a4c0b5
# Predict volume shape:  (13, 13, 13)
# Nodule not in mask:  (80, 200, 56)
# Nodule not in mask:  (80, 128, 80)
# Nodule not in mask:  (80, 152, 80)
# 到目前位置检测到的结节数量：  465
# 0.002008703768862024
# Done in :  1273.430174  seconds
# patient_id:  e1e47812eecd80466cf7f5b0160de446
# Predict volume shape:  (12, 11, 11)
# Nodule not in mask:  (56, 128, 80)
# 到目前位置检测到的结节数量：  465
# 0.0010774546798295876
# Done in :  1279.751837  seconds
# patient_id:  e1c92d3f85a37bd8bb963345b6d66e03
# Predict volume shape:  (9, 9, 9)
# 到目前位置检测到的结节数量：  465
# 5.8863317722414705e-05
# Done in :  1283.44869  seconds
# patient_id:  e188bdeea72bb41d980dc2556dc8aafa
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  465
# 0.0013488950373552082
# Done in :  1289.557712  seconds
# patient_id:  e163325ccf00afde107c80dfce2bce80
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (80, 200, 32)
# Nodule not in mask:  (104, 176, 56)
# 到目前位置检测到的结节数量：  465
# 0.0012028716310016165
# Done in :  1297.494979  seconds
# patient_id:  e1584618a0c72f124fe618e1ed9b3e55
# ...
# 到目前位置检测到的结节数量：  3321
# 0.000817507120401062
# Done in :  10252.763629  seconds
# patient_id:  0ddeb08e9c97227853422bd71a2a695e
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (80, 200, 104)
# Nodule not in mask:  (104, 200, 104)
# 到目前位置检测到的结节数量：  3321
# 0.0011373037514533816
# Done in :  10262.3881  seconds
# patient_id:  0d941a3ad6c889ac451caf89c46cb92a
# Predict volume shape:  (13, 9, 9)
# Nodule not in mask:  (80, 128, 56)
# Nodule not in mask:  (80, 151, 56)
# 到目前位置检测到的结节数量：  3321
# 0.0016032088172328643
# Done in :  10267.924515  seconds
# patient_id:  0d2fcf787026fece4e57be167d079383
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 128, 32)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  3321
# 0.0010563346036154297
# Done in :  10274.442769  seconds
# patient_id:  0d19f1c627df49eb223771c28548350e
# Predict volume shape:  (13, 13, 13)
# 到目前位置检测到的结节数量：  3329
# 0.0038493644502379932
# Done in :  10283.290115  seconds
# patient_id:  0d06d764d3c07572074d468b4cff954f
# Predict volume shape:  (10, 15, 15)
# Nodule not in mask:  (128, 248, 56)
# Nodule not in mask:  (128, 272, 56)
# 到目前位置检测到的结节数量：  3329
# 0.0010749787278153333
# Done in :  10291.260467  seconds
# patient_id:  0ca943d821204ceb089510f836a367fd
# Predict volume shape:  (10, 10, 10)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  3333
# 0.004728626082909597
# Done in :  10296.362089  seconds
# patient_id:  0c9d8314f9c69840e25febabb1229fa4
# Predict volume shape:  (14, 11, 11)
# 到目前位置检测到的结节数量：  3333
# 0.0004512144265205288
# Done in :  10304.189485  seconds
# patient_id:  0c98fcb55e3f36d0c2b6507f62f4c5f1
# Predict volume shape:  (13, 12, 12)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (104, 104, 56)
# Nodule not in mask:  (80, 128, 56)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  3333
# 0.0026354976361443855
# Done in :  10313.098873  seconds
# patient_id:  0c60f4b87afcb3e2dfa65abbbf3ef2f9
# Predict volume shape:  (9, 12, 12)
# 到目前位置检测到的结节数量：  3340
# 0.005778014285242986
# Done in :  10319.134541  seconds
# patient_id:  0c59313f52304e25d5a7dcf9877633b1
# Predict volume shape:  (10, 14, 14)
# Nodule not in mask:  (80, 176, 80)
# Nodule not in mask:  (80, 200, 80)
# 到目前位置检测到的结节数量：  3340
# 0.0019920456951064585
# Done in :  10327.048414  seconds
# patient_id:  0c37613214faddf8701ca41e6d43f56e
# Predict volume shape:  (11, 13, 13)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  3341
# 0.0012900391313546964
# Done in :  10334.485072  seconds
# patient_id:  0c0de3749d4fe175b7a5098b060982a1
# Predict volume shape:  (11, 13, 13)
# Nodule not in mask:  (104, 176, 80)
# 到目前位置检测到的结节数量：  3345
# 0.0033119648969734674
# Done in :  10341.558046  seconds
# patient_id:  0bd0e3056cbf23a1cb7f0f0b18446068
# Predict volume shape:  (12, 12, 12)
# 到目前位置检测到的结节数量：  3345
# 0.00042726669918607404
# Done in :  10348.594302  seconds
# patient_id:  0b20184e0cd497028bdd155d9fb42dc9
# Predict volume shape:  (12, 13, 13)
# Nodule not in mask:  (80, 176, 80)
# Nodule not in mask:  (80, 224, 80)
# Nodule not in mask:  (104, 224, 80)
# 到目前位置检测到的结节数量：  3345
# 0.000981382659159019
# Done in :  10356.909403  seconds
# patient_id:  0acbebb8d463b4b9ca88cf38431aac69
# Predict volume shape:  (13, 9, 9)
# Nodule not in mask:  (128, 104, 56)
# 到目前位置检测到的结节数量：  3353
# 0.008853908208196187
# Done in :  10363.054406  seconds
# patient_id:  0a38e7597ca26f9374f8ea2770ba870d
# Predict volume shape:  (9, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  3360
# 0.009006858625902307
# Done in :  10368.763636  seconds
# patient_id:  0a0c32c9e08cc2ea76a71649de56be6d
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (104, 128, 32)
# Nodule not in mask:  (104, 152, 32)
# Nodule not in mask:  (56, 176, 32)
# Nodule not in mask:  (104, 176, 32)
# 到目前位置检测到的结节数量：  3360
# 0.001860456287432039
# Done in :  10376.380761  seconds
# patient_id:  0a099f2549429d29b32f349e95fb2244
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  3360
# 0.0006686539662199836
# Done in :  10383.095859  seconds
# patient_id:  09fdf599084b816247ba38d95b3c9d80
# Predict volume shape:  (10, 10, 10)
# 到目前位置检测到的结节数量：  3360
# 0.0007742046521736021
# Done in :  10388.107983  seconds
# patient_id:  09ee522a3b7dbea48aa6d39afe240129
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (104, 128, 104)
# 到目前位置检测到的结节数量：  3360
# 0.0021992033331778614
# Done in :  10396.234594  seconds
# patient_id:  09d7c4a3e1076dcfcae2b0a563a28364
# Predict volume shape:  (13, 12, 12)
# Nodule not in mask:  (56, 200, 32)
# Nodule not in mask:  (104, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  3368
# 0.006493175749144177
# Done in :  10404.61917  seconds
# patient_id:  09b1c678fc1009d84a038cd879be4198
# Predict volume shape:  (10, 12, 12)
# Nodule not in mask:  (104, 152, 32)
# Nodule not in mask:  (80, 128, 56)
# 到目前位置检测到的结节数量：  3368
# 0.0013819037707310557
# Done in :  10410.413176  seconds
# patient_id:  099cec971282b1531d297e5d0d423598
# Predict volume shape:  (8, 12, 12)
# Nodule not in mask:  (80, 128, 32)
# 到目前位置检测到的结节数量：  3368
# 0.0010233405475716247
# Done in :  10415.539868  seconds
# patient_id:  08acb3440eb23385724d006403feb585
# Predict volume shape:  (14, 14, 14)
# Nodule not in mask:  (104, 152, 80)
# Nodule not in mask:  (104, 176, 80)
# Nodule not in mask:  (128, 128, 104)
# Nodule not in mask:  (104, 152, 104)
# Nodule not in mask:  (128, 152, 104)
# Nodule not in mask:  (152, 128, 128)
# 到目前位置检测到的结节数量：  3368
# 0.001872357592782099
# Done in :  10425.942347  seconds
# patient_id:  089b8f10743e449a0f64f8f311dd8a46
# Predict volume shape:  (13, 13, 13)
# 到目前位置检测到的结节数量：  3368
# 0.0004168408402964557
# Done in :  10434.495372  seconds
# patient_id:  0890a698c0a6ce5db48b1467011bf8d2
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (104, 128, 56)
# 到目前位置检测到的结节数量：  3368
# 0.0010068410863876597
# Done in :  10441.598146  seconds
# patient_id:  086f95a932c83faed289854083f48831
# Predict volume shape:  (13, 14, 14)
# 到目前位置检测到的结节数量：  3379
# 0.004445932326991716
# Done in :  10451.573722  seconds
# patient_id:  08643d7b9ce18405fb63f63dda258e76
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (80, 224, 56)
# 到目前位置检测到的结节数量：  3379
# 0.0006174967170777948
# Done in :  10460.797738  seconds
# patient_id:  0852f5124d69d7f8cd35fa31e1364d29
# Predict volume shape:  (13, 12, 12)
# Nodule not in mask:  (56, 176, 32)
# 到目前位置检测到的结节数量：  3379
# 0.0008074570401239092
# Done in :  10469.01425  seconds
# patient_id:  08528b8817429d12b7ce2bf444d264f9
# Predict volume shape:  (4, 14, 14)
# 到目前位置检测到的结节数量：  3379
# 2.5614562644690807e-07
# Done in :  10472.163975  seconds
# patient_id:  081f4a90f24ac33c14b61b97969b7f81
# Predict volume shape:  (11, 13, 13)
# 到目前位置检测到的结节数量：  3397
# 0.010097248506126574
# Done in :  10479.17114  seconds
# patient_id:  080e6a00e69888fd620894f9fd0714b1
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (104, 152, 56)
# Nodule not in mask:  (104, 176, 56)
# 到目前位置检测到的结节数量：  3397
# 0.001378895545898915
# Done in :  10487.827924  seconds
# patient_id:  07fdb853ff90ce3c6d5c91f619ed714e
# Predict volume shape:  (13, 13, 13)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  3397
# 0.0008920781511706007
# Done in :  10497.446945  seconds
# patient_id:  07bca4290a2530091ce1d5f200d9d526
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  3401
# 0.004218942329195542
# Done in :  10505.140191  seconds
# patient_id:  07b1defcfae5873ee1f03c90255eb170
# Predict volume shape:  (10, 11, 11)
# Nodule not in mask:  (56, 152, 32)
# Nodule not in mask:  (56, 176, 32)
# Nodule not in mask:  (104, 104, 56)
# Nodule not in mask:  (56, 128, 56)
# Nodule not in mask:  (80, 128, 56)
# Nodule not in mask:  (56, 152, 56)
# 到目前位置检测到的结节数量：  3407
# 0.009878594521360869
# Done in :  10511.37682  seconds
# patient_id:  07abb7bec548d1c0ccef088ce934e517
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  3407
# 0.0014175769876777296
# Done in :  10518.826769  seconds
# patient_id:  07349deeea878c723317a1ce42cc7e58
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (80, 176, 32)
# Nodule not in mask:  (56, 200, 32)
# Nodule not in mask:  (56, 224, 32)
# Nodule not in mask:  (80, 224, 32)
# 到目前位置检测到的结节数量：  3415
# 0.006359434438514789
# Done in :  10526.671931  seconds
# patient_id:  0708c00f6117ed977bbe1b462b56848c
# Predict volume shape:  (13, 10, 10)
# Nodule not in mask:  (80, 128, 32)
# 到目前位置检测到的结节数量：  3417
# 0.0024870400868351253
# Done in :  10533.35542  seconds
# patient_id:  0700108170c91ea2219006e9484999ef
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (80, 128, 32)
# Nodule not in mask:  (80, 152, 32)
# 到目前位置检测到的结节数量：  3417
# 0.0011132956284787851
# Done in :  10540.995616  seconds
# patient_id:  06a90409e4fcea3e634748b967993531
# Predict volume shape:  (9, 12, 12)
# 到目前位置检测到的结节数量：  3417
# 0.0008488981261880716
# Done in :  10546.637969  seconds
# patient_id:  0679e5fd67b7441b8094494033f3881f
# Predict volume shape:  (12, 11, 11)
# 到目前位置检测到的结节数量：  3417
# 0.0010014878549849196
# Done in :  10553.669193  seconds
# patient_id:  064366faa1a83fdcb18b2538f1717290
# Predict volume shape:  (12, 12, 12)
# 到目前位置检测到的结节数量：  3424
# 0.004826152134826396
# Done in :  10561.664676  seconds
# patient_id:  05a20caf6ab6df4643644c953f06a5eb
# Predict volume shape:  (11, 11, 11)
# Nodule not in mask:  (56, 176, 32)
# 到目前位置检测到的结节数量：  3426
# 0.0027279286378021814
# Done in :  10567.98446  seconds
# patient_id:  059d8c14b2256a2ba4e38ac511700203
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (80, 200, 56)
# 到目前位置检测到的结节数量：  3445
# 0.009786822094489311
# Done in :  10576.543355  seconds
# patient_id:  05609fdb8fa0895ac8a9be373144dac7
# Predict volume shape:  (9, 14, 14)
# 到目前位置检测到的结节数量：  3445
# 0.0006651926619366502
# Done in :  10583.818977  seconds
# patient_id:  04fca9fbec0b803326488ade96897f6e
# Predict volume shape:  (12, 11, 11)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  3445
# 0.0007635103106393036
# Done in :  10590.632376  seconds
# patient_id:  04e5d435fa01b0958e3274be73312cac
# Predict volume shape:  (12, 11, 11)
# 到目前位置检测到的结节数量：  3445
# 0.0002455411703688349
# Done in :  10597.385235  seconds
# patient_id:  04cfc5efa4c8c2a8944c8b9fa6cb04d1
# Predict volume shape:  (11, 13, 13)
# Nodule not in mask:  (80, 152, 56)
# 到目前位置检测到的结节数量：  3445
# 0.0007216598180258097
# Done in :  10605.020563  seconds
# patient_id:  04a8c47583142181728056310759dea1
# Predict volume shape:  (10, 12, 12)
# Nodule not in mask:  (104, 152, 56)
# Nodule not in mask:  (104, 176, 56)
# Nodule not in mask:  (104, 200, 56)
# Nodule not in mask:  (104, 248, 80)
# Nodule not in mask:  (128, 248, 80)
# Nodule not in mask:  (104, 272, 80)
# Nodule not in mask:  (128, 272, 80)
# 到目前位置检测到的结节数量：  3449
# 0.007453656983808026
# Done in :  10611.516821  seconds
# patient_id:  04a52f49cdbfb8b99789b9e93f1ad319
# Predict volume shape:  (10, 12, 12)
# 到目前位置检测到的结节数量：  3453
# 0.004120228017881992
# Done in :  10617.651208  seconds
# patient_id:  04a3187ec2ed4198a25033071897bffc
# Predict volume shape:  (10, 13, 13)
# Nodule not in mask:  (80, 152, 32)
# Nodule not in mask:  (80, 176, 32)
# Nodule not in mask:  (104, 176, 32)
# 到目前位置检测到的结节数量：  3453
# 0.0022975648782302223
# Done in :  10624.94058  seconds
# patient_id:  0482c444ac838adc5aa00d1064c976c1
# Predict volume shape:  (9, 13, 13)
# 到目前位置检测到的结节数量：  3453
# 0.0006606652464041719
# Done in :  10631.030422  seconds
# patient_id:  043ed6cb6054cc13804a3dca342fa4d0
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (56, 176, 32)
# 到目前位置检测到的结节数量：  3453
# 0.0006151856100027968
# Done in :  10638.531703  seconds
# patient_id:  03ff23e445787886f8b0cb192b3c154d
# Predict volume shape:  (12, 11, 11)
# 到目前位置检测到的结节数量：  3461
# 0.006139773284722779
# Done in :  10645.764563  seconds
# patient_id:  03fb0d0fdb187ee1160f09386b28c3f2
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  3461
# 4.53943582613987e-05
# Done in :  10652.373331  seconds
# patient_id:  03bd22ed5858039af223c04993e9eb22
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (104, 176, 32)
# Nodule not in mask:  (104, 200, 32)
# 到目前位置检测到的结节数量：  3469
# 0.004253226024400645
# Done in :  10661.905732  seconds
# patient_id:  0334c8242ce7ee1a6c1263096e4cc535
# Predict volume shape:  (13, 12, 12)
# Nodule not in mask:  (80, 128, 32)
# Nodule not in mask:  (56, 152, 32)
# 到目前位置检测到的结节数量：  3483
# 0.00882182544023326
# Done in :  10670.172748  seconds
# patient_id:  031b7ec4fe96a3b035a8196264a8c8c3
# Predict volume shape:  (13, 14, 14)
# 到目前位置检测到的结节数量：  3488
# 0.002521913289718044
# Done in :  10681.000368  seconds
# patient_id:  028996723faa7840bb57f57e28275e4c
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 152, 56)
# Nodule not in mask:  (80, 176, 56)
# 到目前位置检测到的结节数量：  3492
# 0.003966736669197204
# Done in :  10687.840498  seconds
# patient_id:  02801e3bbcc6966cb115a962012c35df
# Predict volume shape:  (12, 12, 12)
# 到目前位置检测到的结节数量：  3492
# 0.000608026937249883
# Done in :  10695.706887  seconds
# patient_id:  026be5d5e652b6a7488669d884ebe297
# Predict volume shape:  (9, 10, 10)
# Nodule not in mask:  (104, 104, 32)
# Nodule not in mask:  (56, 128, 32)
# 到目前位置检测到的结节数量：  3492
# 0.0023540250412532626
# Done in :  10700.47751  seconds
# patient_id:  0268f3a7a17412178cfb039e71799a80
# Predict volume shape:  (11, 12, 12)
# 到目前位置检测到的结节数量：  3492
# 0.0006721063400649625
# Done in :  10707.16289  seconds
# patient_id:  026470d51482c93efc18b9803159c960
# Predict volume shape:  (12, 14, 14)
# Nodule not in mask:  (128, 224, 56)
# 到目前位置检测到的结节数量：  3492
# 0.0005473040039639314
# Done in :  10716.289038  seconds
# patient_id:  0257df465d9e4150adef13303433ff1e
# Predict volume shape:  (13, 11, 11)
# Nodule not in mask:  (80, 128, 32)
# Nodule not in mask:  (56, 176, 32)
# 到目前位置检测到的结节数量：  3503
# 0.007920409193216961
# Done in :  10724.053916  seconds
# patient_id:  024efb7a1e67dc820eb61cbdaa090166
# Predict volume shape:  (12, 18, 18)
# 到目前位置检测到的结节数量：  3503
# 0.0001082244852517541
# Done in :  10735.427242  seconds
# patient_id:  01f1140c8e951e2a921b61c9a7e782c2
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  3503
# 0.0007984510834833901
# Done in :  10742.637162  seconds
# patient_id:  01e349d34c06410e1da273add27be25c
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (104, 128, 32)
# Nodule not in mask:  (104, 152, 32)
# 到目前位置检测到的结节数量：  3503
# 0.001677297897615923
# Done in :  10749.793891  seconds
# patient_id:  01de8323fa065a8963533c4a86f2f6c1
# Predict volume shape:  (10, 12, 12)
# 到目前位置检测到的结节数量：  3503
# 0.000552738005962905
# Done in :  10756.160771  seconds
# patient_id:  013395589c01aa01f8df81d80fb0e2b8
# Predict volume shape:  (10, 9, 9)
# Nodule not in mask:  (80, 151, 32)
# 到目前位置检测到的结节数量：  3503
# 0.001671144818802844
# Done in :  10761.018632  seconds
# patient_id:  0121c2845f2b7df060945b072b2515d7
# Predict volume shape:  (12, 12, 12)
# 到目前位置检测到的结节数量：  3503
# 0.0010631158595456691
# Done in :  10768.932938  seconds
# patient_id:  00edff4f51a893d80dae2d42a7f45ad1
# Predict volume shape:  (12, 12, 12)
# 到目前位置检测到的结节数量：  3503
# 0.001110654763470374
# Done in :  10776.298016  seconds
# patient_id:  00cba091fa4ad62cc3200a657aeb957e
# Predict volume shape:  (12, 11, 11)
# 到目前位置检测到的结节数量：  3513
# 0.007428559486035081
# Done in :  10783.130287  seconds
# patient_id:  00986bebc45e12038ef0ce3e9962b51a
# Predict volume shape:  (11, 12, 12)
# Nodule not in mask:  (80, 176, 32)
# 到目前位置检测到的结节数量：  3513
# 0.001472476188653598
# Done in :  10790.317398  seconds
# patient_id:  0092c13f9e00a3717fdc940641f00015
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (104, 176, 80)
# Nodule not in mask:  (80, 176, 104)
# 到目前位置检测到的结节数量：  3522
# 0.0069698116799905025
# Done in :  10797.811024  seconds
# patient_id:  008464bb8521d09a42985dd8add3d0d2
# Predict volume shape:  (10, 13, 13)
# 到目前位置检测到的结节数量：  3530
# 0.005999009352427406
# Done in :  10804.850077  seconds
# patient_id:  006b96310a37b36cccb2ab48d10b49a3
# Predict volume shape:  (12, 12, 12)
# Nodule not in mask:  (56, 176, 56)
# Nodule not in mask:  (80, 128, 80)
# 到目前位置检测到的结节数量：  3545
# 0.00977858884171657
# Done in :  10812.550161  seconds
# patient_id:  003f41c78e6acfa92430a057ac0b306e
# Predict volume shape:  (12, 15, 15)
# 到目前位置检测到的结节数量：  3545
# 0.00043542379355521616
# Done in :  10823.37418  seconds
# patient_id:  0030a160d58723ff36d73f41b170ec21
# Predict volume shape:  (12, 10, 10)
# 到目前位置检测到的结节数量：  3553
# 0.006880224358753315
# Done in :  10829.59782  seconds
# patient_id:  0015ceb851d7251b8f399e39779d1e7d
# Predict volume shape:  (14, 13, 13)
# 到目前位置检测到的结节数量：  3553
# 0.0008125423549345126
# Done in :  10838.813949  seconds

# %%
def predict_cubes(model_path, magnification, ext_name=""):
  
    dst_dir = settings.NDSB3_NODULE_DETECTION_DIR_CNN
    
    if not os.path.exists(dst_dir):
        os.makedirs(dst_dir)
    
    dst_dir += "predictions" + str(int(magnification * 10)) + "_" + ext_name + "/"
    
    if not os.path.exists(dst_dir):
        os.makedirs(dst_dir)

    #计时器
    sw = helpers.Stopwatch.start_new()
    
    #读取detector的model
    model = Nodule_Detector_CNN.get_net(load_weight_path=model_path)
     
    patient_ids = []

    #读取数据里所有病人的ID
    for file_name in os.listdir(settings.NDSB3_EXTRACTED_IMAGE_DIR):
        
        if not os.path.isdir(settings.NDSB3_EXTRACTED_IMAGE_DIR + file_name):
            continue
        if file_name == "_labels":
            continue
        patient_ids.append(file_name)
    
    #对所有病人进行逐一诊断
    all_predictions_csv = []
    
    total_nodule=0
    
    for patient_index, patient_id in enumerate(reversed(patient_ids)):
        
        print("patient_id: ",patient_id)
    
        csv_target_path = dst_dir + patient_id + ".csv"
        
        #读取CT图像
        patient_img = helpers.load_patient_images(patient_id, settings.NDSB3_EXTRACTED_IMAGE_DIR, "*_i.png", [])
        
        #调整Scale
        if magnification != 1:
            patient_img = helpers.rescale_patient_images(patient_img, (1, 1, 1), magnification)
        
        #读取Mask
        patient_mask = helpers.load_patient_images(patient_id, settings.NDSB3_EXTRACTED_IMAGE_DIR, "*_m.png", [])
        
        #调整Scale
        if magnification != 1:
            patient_mask = helpers.rescale_patient_images(patient_mask, (1, 1, 1), magnification, is_mask_image=True)

        # Step 和 Cube
        step = PREDICT_STEP
        CROP_SIZE = CUBE_SIZE

        #各个维度的窗口滑动次数
        predict_volume_shape_list = [0, 0, 0]
        
        for dim in range(3):
            
            dim_indent = 0
            
            while dim_indent + CROP_SIZE < patient_img.shape[dim]:
                
                predict_volume_shape_list[dim] += 1
                
                dim_indent += step
        
        #predict_volume用来存储各个维度每次滑动的预测结果
        predict_volume_shape = (predict_volume_shape_list[0], predict_volume_shape_list[1], predict_volume_shape_list[2])
        predict_volume = numpy.zeros(shape=predict_volume_shape, dtype=float)
        print("Predict volume shape: ", predict_volume.shape)
        
        #需要扫描的次数
        scan_number = predict_volume_shape_list[0] * predict_volume_shape_list[1] * predict_volume_shape_list[2] 
        #当前扫描的次数
        done_count = 0      
        
        skipped_count = 0 
        batch_size = 128
        batch_list = []
        batch_list_coords = []
        patient_predictions_csv = []
        cube_img = None
        annotation_index = 0

        for z in range(0, predict_volume_shape[0]):
            
            for y in range(0, predict_volume_shape[1]):
                
                for x in range(0, predict_volume_shape[2]):
                    
                    #获取一个cube
                    cube_img = patient_img[z * step:z * step+CROP_SIZE, y * step:y * step + CROP_SIZE, x * step:x * step+CROP_SIZE]
                    cube_mask = patient_mask[z * step:z * step+CROP_SIZE, y * step:y * step + CROP_SIZE, x * step:x * step+CROP_SIZE]

                    #如果cube位于肺的外面，则不进行判断，直接跳过
                    if cube_mask.sum() < 2000:
                        
                        skipped_count += 1
                        
                    else:
                                
                        img_prep = prepare_image_for_net3D(cube_img)
                        
                        #Cube的列表
                        batch_list.append(img_prep)  
                        
                        #坐标的列表
                        batch_list_coords.append((z, y, x))
                        
                        #如果凑够了128个就开始预测 或者到最后一个了
                        if len(batch_list) % batch_size == 0 or done_count==(scan_number-1):
                            
                            #进行预测
                            batch_data = numpy.vstack(batch_list)         
                            p = model.predict(batch_data, batch_size=batch_size)
                                 
                            for i in range(len(p)):
                                
                                p_z = batch_list_coords[i][0]
                                p_y = batch_list_coords[i][1]
                                p_x = batch_list_coords[i][2]
                                
                                #存储预测结果
                                nodule_chance = p[i][0]
                                predict_volume[p_z, p_y, p_x] = nodule_chance
                        
                                #保存被判断为postive的nodule的坐标和Size
                                if nodule_chance > P_TH:
                                    
                                    p_z = p_z * step + CROP_SIZE / 2
                                    p_y = p_y * step + CROP_SIZE / 2
                                    p_x = p_x * step + CROP_SIZE / 2
                                    
                                    #Nodule坐标
                                    p_z_perc = round(p_z / patient_img.shape[0], 4)
                                    p_y_perc = round(p_y / patient_img.shape[1], 4)
                                    p_x_perc = round(p_x / patient_img.shape[2], 4)
                                    
                                    #Nodule的概率
                                    nodule_chance = round(nodule_chance, 4)
                                    
                                    patient_predictions_csv_line = [annotation_index, p_x_perc, p_y_perc, p_z_perc, nodule_chance]
                                    patient_predictions_csv.append(patient_predictions_csv_line)
                                    
                                    all_predictions_csv.append([patient_id] + patient_predictions_csv_line)
                                    annotation_index += 1

                            batch_list = []
                            batch_list_coords = []
                            
                    done_count += 1
                    
                    #每检测出10000个positive nodule 就输出一下
                    if done_count % 10000 == 0:
                        print("Done: ", done_count, " skipped:", skipped_count)
                    
        df = pandas.DataFrame(patient_predictions_csv, columns=["anno_index", "coord_x", "coord_y", "coord_z", "nodule_chance"])
        
        filter_patient_nodules_predictions(df, patient_id, CROP_SIZE * magnification)
        
        #到目前为止检测到多少个nodule
        total_nodule+=len(df)
        print("到目前位置检测到的结节数量： ",total_nodule)
        
        df.to_csv(csv_target_path, index=False)

        print(predict_volume.mean())
        
        print("Done in : ", sw.get_elapsed_seconds(), " seconds")

# %%
def prepare_image_for_net3D(img):
    img = img.astype(numpy.float32)
    img -= MEAN_PIXEL_VALUE
    img /= 255.
    img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2], 1)
    return img

# %%
def filter_patient_nodules_predictions(df_nodule_predictions: pandas.DataFrame, patient_id, view_size):
    
    src_dir = settings.NDSB3_EXTRACTED_IMAGE_DIR
    
    patient_mask = helpers.load_patient_images(patient_id, src_dir, "*_m.png")
    
    delete_indices = []
    
    for index, row in df_nodule_predictions.iterrows():
        
        z_perc = row["coord_z"]
        y_perc = row["coord_y"]
        x_perc = row["coord_x"]
        center_x = int(round(x_perc * patient_mask.shape[2]))
        center_y = int(round(y_perc * patient_mask.shape[1]))
        center_z = int(round(z_perc * patient_mask.shape[0]))

        start_y = center_y - view_size / 2
        start_x = center_x - view_size / 2
        
        nodule_in_mask = False
        
        for z_index in [-1, 0, 1]:
            
            img = patient_mask[z_index + center_z]
            
            start_x = int(start_x)
            start_y = int(start_y)
            view_size = int(view_size)
            
            img_roi = img[start_y:start_y+view_size, start_x:start_x + view_size]
            
            if img_roi.sum() > 255:  # more than 1 pixel of mask.
                nodule_in_mask = True

        if not nodule_in_mask:
            
            print("Nodule not in mask: ", (center_x, center_y, center_z))
            delete_indices.append(index)
            
        else:
            
            #可能是太低的位置一般没有Nodule
            if center_z < 30:
                print("Z < 30: ", patient_id, " center z:", center_z, " y_perc: ",  y_perc)
                delete_indices.append(index)
            
            #有可能是假阳性
            if (z_perc > 0.75 or z_perc < 0.25) and y_perc > 0.85:
                print("SUSPICIOUS FALSEPOSITIVE: ", patient_id, " center z:", center_z, " y_perc: ",  y_perc)
                delete_indices.append(index)
            
            #假阳性范围外
            if center_z < 50 and y_perc < 0.30:
                print("SUSPICIOUS FALSEPOSITIVE OUT OF RANGE: ", patient_id, " center z:", center_z, " y_perc: ",  y_perc)
                delete_indices.append(index)
    
    df_nodule_predictions.drop(df_nodule_predictions.index[delete_indices], inplace=True)
    
    return df_nodule_predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a91075e87917> in <module>()
# ----> 1 def filter_patient_nodules_predictions(df_nodule_predictions: pandas.DataFrame, patient_id, view_size):
#       2
#       3     src_dir = settings.NDSB3_EXTRACTED_IMAGE_DIR
#       4
#       5     patient_mask = helpers.load_patient_images(patient_id, src_dir, "*_m.png")
#
# NameError: name 'pandas' is not defined

# %%
a.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d74f1bcdd37c> in <module>()
# ----> 1 a.shape
#
# NameError: name 'a' is not defined

# %%
import pandas

# %%
a=[]

# %%
b=[1,2,3]
b=pandas.DataFrame(b)

# %%
a.append(1)

# %%
a
# Out:
# [1, 1]

# %%
b.drop(a)
# Out:
#    0
# 0  1
# 2  3
